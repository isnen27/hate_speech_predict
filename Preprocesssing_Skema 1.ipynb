# %%
import pandas as pd 
import numpy as np

TWEET_DATA = pd.read_csv("dataHS_002.csv")

TWEET_DATA.head(10)
TWEET_DATA.loc[12:21,['Content','Label']]
# Out:
#                                               Content  Label
# 12  @adnrahman Betul apa ustazah tu cakap\n\nIn ma...      4
# 13  RT @zucowi: @fpoemsh Krn demokrat menormalisas...      4
# 14  RT @Widyarenee: Ini penting u/ terus diingatka...      4
# 15  RT @menghanyurkan: kalau sendernya bukan agama...      4
# 16  RT @satriohendri: Akhirnya @hariankompas yang ...      3
# 17  7. Muhaimin Iskandar : 85,4%\n8. Puan Maharani...      4
# 18  1. Prabowo Subianto : 96,7%\n2. Ganjar Pranowo...      4
# 19  Prabowo Subianto unggul dari Gubernur Jawa Ten...      4
# 20  RT @aciigulung: udah segender, beda agama lagi...      4
# 21                        @Maudy_Kadrun Gambar aki2mu      2

# %%
# ------ Case Folding --------
# use function Series.str.lower() from Pandas
TWEET_DATA['Content'] = TWEET_DATA['Content'].str.lower()


print('Case Folding Result : \n')
print(TWEET_DATA['Content'].head(10))
print('\n\n\n')
# Out:
# Case Folding Result :
#
# 0    pasal 25 uu tpks padahal udah dibilang kalau k...
# 1    @onedarwanto @kanjeng2022 @__rismawidiono_ � h...
# 2    @abingsanca karena mereka masih memiliki angga...
# 3    rt @laingenlisa: pihaknya akan menggandeng kem...
# 4    rt @rstmbcl: di bully, diserang, dipojokan, da...
# 5    @agama_nusantara mui sebaiknya bekerja keras u...
# 6    pak ganjar pranowo bikin ngakak saja, sudah be...
# 7    demi apapun ya anjir kalo gue di masa depan be...
# 8    rt @iwanalidarmawan: siang ini mereka yang men...
# 9    halang kenderaan dan buat gangguan seksual, pe...
# Name: Content, dtype: object

# %%
import string 
import re #regex library

# import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize 
from nltk.probability import FreqDist

# ------ Tokenizing ---------

def remove_tweet_special(text):
    # remove tab, new line, ans back slice
    text = text.replace('\\t'," ").replace('\\n'," ").replace('\\u'," ").replace('\\',"")
    # remove non ASCII (emoticon, chinese word, .etc)
    text = text.encode('ascii', 'replace').decode('ascii')
    # remove mention, link, hashtag
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)"," ", text).split())
    # remove incomplete URL
    return text.replace("http://", " ").replace("https://", " ")
                
TWEET_DATA['Content'] = TWEET_DATA['Content'].apply(remove_tweet_special)

#remove number
def remove_number(text):
    return  re.sub(r"\d+", "", text)

TWEET_DATA['Content'] = TWEET_DATA['Content'].apply(remove_number)

#remove punctuation
def remove_punctuation(text):
    return text.translate(str.maketrans("","",string.punctuation))

TWEET_DATA['Content'] = TWEET_DATA['Content'].apply(remove_punctuation)

#remove whitespace leading & trailing
def remove_whitespace_LT(text):
    return text.strip()

TWEET_DATA['Content'] = TWEET_DATA['Content'].apply(remove_whitespace_LT)

#remove multiple whitespace into single whitespace
def remove_whitespace_multiple(text):
    return re.sub('\s+',' ',text)

TWEET_DATA['Content'] = TWEET_DATA['Content'].apply(remove_whitespace_multiple)

# remove single char
def remove_singl_char(text):
    return re.sub(r"\b[a-zA-Z]\b", "", text)

TWEET_DATA['Content'] = TWEET_DATA['Content'].apply(remove_singl_char)

# NLTK word rokenize 
def word_tokenize_wrapper(text):
    return word_tokenize(text)

TWEET_DATA['tweet_tokens'] = TWEET_DATA['Content'].apply(word_tokenize_wrapper)

print('Tokenizing Result : \n') 
print(TWEET_DATA['tweet_tokens'].head(10))
print('\n\n\n')
# Out:
# Tokenizing Result :
#
# 0    [pasal, uu, tpks, padahal, udah, dibilang, kal...
# 1                                       [rismawidiono]
# 2    [karena, mereka, masih, memiliki, anggapan, ba...
# 3    [rt, pihaknya, akan, menggandeng, kemenag, unt...
# 4    [rt, di, bully, diserang, dipojokan, dari, seg...
# 5    [nusantara, mui, sebaiknya, bekerja, keras, un...
# 6    [pak, ganjar, pranowo, bikin, ngakak, saja, su...
# 7    [demi, apapun, ya, anjir, kalo, gue, di, masa,...
# 8    [rt, siang, ini, mereka, yang, mengatasnamakan...
# 9    [halang, kenderaan, dan, buat, gangguan, seksu...
# Name: tweet_tokens, dtype: object

# %%
# NLTK calc frequency distribution
def freqDist_wrapper(text):
    return FreqDist(text)

TWEET_DATA['tweet_tokens_fdist'] = TWEET_DATA['tweet_tokens'].apply(freqDist_wrapper)

print('Frequency Tokens : \n') 
print(TWEET_DATA['tweet_tokens_fdist'].head(10).apply(lambda x : x.most_common()))
# Out:
# Frequency Tokens :
#
# 0    [(pasal, 1), (uu, 1), (tpks, 1), (padahal, 1),...
# 1                                  [(rismawidiono, 1)]
# 2    [(yg, 3), (karena, 2), (mereka, 2), (memiliki,...
# 3    [(rt, 1), (pihaknya, 1), (akan, 1), (menggande...
# 4    [(rt, 1), (di, 1), (bully, 1), (diserang, 1), ...
# 5    [(nusantara, 1), (mui, 1), (sebaiknya, 1), (be...
# 6    [(ya, 2), (pak, 1), (ganjar, 1), (pranowo, 1),...
# 7    [(gue, 3), (hukum, 3), (di, 2), (sih, 2), (yg,...
# 8    [(rt, 1), (siang, 1), (ini, 1), (mereka, 1), (...
# 9    [(halang, 1), (kenderaan, 1), (dan, 1), (buat,...
# Name: tweet_tokens_fdist, dtype: object

# %%
from nltk.corpus import stopwords

# ----------------------- get stopword from NLTK stopword -------------------------------
# get stopword indonesia
list_stopwords = stopwords.words('indonesian')


# ---------------------------- manualy add stopword  ------------------------------------
# append additional stopword
list_stopwords.extend(["yg", "dg", "rt", "dgn", "ny", "d", 'klo', 
                       'kalo', 'amp', 'biar', 'bikin', 'bilang', 
                       'gak', 'ga', 'krn', 'nya', 'nih', 'sih', 
                       'si', 'tau', 'tdk', 'tuh', 'utk', 'ya', 
                       'jd', 'jgn', 'sdh', 'aja', 'n', 't', 
                       'nyg', 'hehe', 'pen', 'u', 'nan', 'loh', 'rt',
                       '&amp', 'yah','wkwk'])

# ----------------------- add stopword from txt file ------------------------------------
# read txt stopword using pandas
txt_stopword = pd.read_csv("stopword.txt", names= ["stopword"], header = None)

# convert stopword string to list & append additional stopword
list_stopwords.extend(txt_stopword["stopword"][0].split(' '))

# ---------------------------------------------------------------------------------------

# convert list to dictionary
list_stopwords = set(list_stopwords)


#remove stopword pada list token
def stopwords_removal(words):
    return [word for word in words if word not in list_stopwords]

TWEET_DATA['tweet_tokens_WSW'] = TWEET_DATA['tweet_tokens'].apply(stopwords_removal) 

print('Filtering (Stopword Removal) : \n')
print(TWEET_DATA['tweet_tokens_WSW'].head(10))
# Out:
# Filtering (Stopword Removal) :
#
# 0    [pasal, uu, tpks, udah, dibilang, keterangan, ...
# 1                                       [rismawidiono]
# 2    [memiliki, anggapan, teroris, ditangkap, memil...
# 3    [menggandeng, kemenag, mengevaluasi, pondok, p...
# 4    [bully, diserang, dipojokan, arah, hina, cinta...
# 5    [nusantara, mui, keras, mencegah, pelecehan, s...
# 6    [ganjar, pranowo, ngakak, berani, tipu, rakyat...
# 7    [apapun, anjir, gue, bener, sukses, ranah, huk...
# 8    [siang, mengatasnamakan, relawan, ganjar, pran...
# 9    [halang, kenderaan, gangguan, seksual, perbuat...
# Name: tweet_tokens_WSW, dtype: object

# %%
normalizad_word = pd.read_excel("normalisasi-V1.xlsx")

normalizad_word_dict = {}

for index, row in normalizad_word.iterrows():
    if row[0] not in normalizad_word_dict:
        normalizad_word_dict[row[0]] = row[1] 

def normalized_term(document):
    return [normalizad_word_dict[term] if term in normalizad_word_dict else term for term in document]

TWEET_DATA['tweet_normalized'] = TWEET_DATA['tweet_tokens_WSW'].apply(normalized_term)

print('Normalization : \n')
TWEET_DATA['tweet_normalized'].head(10)
# Out:
# Normalization :
# 0    [pasal, uu, tpks, udah, dikatakan, keterangan,...
# 1                                       [rismawidiono]
# 2    [memiliki, anggapan, teroris, ditangkap, memil...
# 3    [menggandeng, kemenag, mengevaluasi, pondok, p...
# 4    [bully, diserang, dipojokan, arah, hina, cinta...
# 5    [nusantara, mui, keras, mencegah, pelecehan, s...
# 6    [ganjar, pranowo, tertawa, berani, tipu, rakya...
# 7    [apapun, waw, aku, benar, sukses, ranah, hukum...
# 8    [siang, mengatasnamakan, relawan, ganjar, pran...
# 9    [halang, kenderaan, gangguan, seksual, perbuat...
# Name: tweet_normalized, dtype: object

# %%
#Delete puntuation from normalized data
# define punctuation
punctuations = '''!()-[]{};:'"\,<>./?@#$%^&*_~'''

my_str = str(TWEET_DATA['tweet_normalized'])


# Delete punctuation from string
TWEET_DATA_PREPO = ""
for char in my_str:
   if char not in punctuations:
       TWEET_DATA_PREPO = TWEET_DATA_PREPO + char
print(TWEET_DATA_PREPO)
# Out:
# 0       pasal uu tpks udah dikatakan keterangan
# 1                                          rismawidiono
# 2       memiliki anggapan teroris ditangkap memil
# 3       menggandeng kemenag mengevaluasi pondok p
# 4       bully diserang dipojokan arah hina cinta
#
# 1676     capres imigran yaman merubah ulama buzzer
# 1677    yaudah biarin yaudah senyumin yaudah lup
# 1678    sapiens iman beriman menemukan tuhan del
# 1679    munafiknya politisasi politik perusak pan
# 1680    prabowo subianto persen ganjar pranowo p
# Name tweetnormalized Length 1681 dtype object

# %%
TWEET_DATA['tweet_normalized'].to_csv("dataHS_01_normal.csv", index=False)

# %%
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter


# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in TWEET_DATA['tweet_normalized']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")


# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]

TWEET_DATA['tweet_tokens_stemmed'] = TWEET_DATA['tweet_normalized'].swifter.apply(get_stemmed_term)
print('Stemmer : \n')
print(TWEET_DATA['tweet_tokens_stemmed'])
# Out:
# 6713
# ------------------------
# pasal : pasal
# uu : uu
# tpks : tpks
# udah : udah
# dikatakan : kata
# keterangan : terang
# korban : korban
# membuktikan : bukti
# pelecehan : leceh
# seksual : seksual
# minimal : minimal
# aparat : aparat
# penegak : tegak
# hukum : hukum
# ikut : ikut
# atas : atas
# berita : berita
# undang undang : undang undang
# bertindak : tindak
# jalur : jalur
# viral : viral
# rismawidiono : rismawidiono
# memiliki : milik
# anggapan : anggap
# teroris : teroris
# ditangkap : tangkap
# keimanan : iman
# menganggap : anggap
# berjuang : juang
# penegakan : tega
# agama : agama
# terorisme : terorisme
# agamanya : agama
# menganjurkan : anjur
# penganutnya : anut
# menggandeng : gandeng
# kemenag : kemenag
# mengevaluasi : evaluasi
# pondok : pondok
# pesantren : pesantren
# lokasi : lokasi
# sekolah : sekolah
# madrasah : madrasah
# bully : bully
# diserang : serang
# dipojokan : pojok
# arah : arah
# hina : hina
# cinta : cinta
# dapatkan : dapat
# cacian : caci
# nusantara : nusantara
# mui : mui
# keras : keras
# mencegah : cegah
# marak : marak
# ganjar : ganjar
# pranowo : pranowo
# tertawa : tertawa
# berani : berani
# tipu : tipu
# rakyat : rakyat
# belum : belum
# warga internet : warga internet
# sekarang : sekarang
# banyak : banyak
# cerdas : cerdas
# kekeliruan : keliru
# komentar : komentar
# gemas : gemas
# dalai : dalai
# koruptor : koruptor
# anas : anas
# urbaningrum : urbaningrum
# umur : umur
# agnes : agnes
# madrid : madrid
# chelsea : chelsea
# champions : champions
# league : league
# manchaster : manchaster
# city : city
# monas : monas
# benzema : benzema
# apapun : apa
# waw : waw
# aku : aku
# benar : benar
# sukses : sukses
# ranah : ranah
# semacamnya : macam
# ingin : ingin
# ubah : ubah
# kebiri : kebiri
# mematikan : mati
# hawa : hawa
# napsu : napsu
# pelaku : laku
# jujur : jujur
# tidak suka : tidak suka
# mati : mati
# mudah : mudah
# tinggal : tinggal
# doang : doang
# siang : siang
# mengatasnamakan : mengatasnamakan
# relawan : rawan
# membagikan : bagi
# kaos : kaos
# dompet : dompet
# rumah : rumah
# warga : warga
# halang : halang
# kenderaan : kenderaan
# gangguan : ganggu
# perbuatan : buat
# pemandu : pandu
# kelisa : kelisa
# undang : undang
# kemarahan : marah
# udahlah : udahlah
# cholil : cholil
# berpolemik : polemik
# jalankan : jalan
# sesuai : sesuai
# konstitusi : konstitusi
# lakukanlah : laku
# jel : jel
# kacer : kacer
# bahrawi : bahrawi
# lebar : lebar
# nulis : nulis
# semangatnya : semangat
# hnya : hnya
# rasis : ras
# kebencian : benci
# keturunan : turun
# cina : cina
# warna : warna
# it : it
# ustazah : ustazah
# tu : tu
# cakap : cakap
# in : in
# marriage : marriage
# ni : ni
# sometimes : sometimes
# mak : mak
# ajar : ajar
# so : so
# isterisuami : isterisuami
# kena : kena
# belajar : ajar
# orang : orang
# diajar : ajar
# bodoh : bodoh
# sombong : sombong
# tunggang : tunggang
# jugak : jugak
# demokrat : demokrat
# menormalisasi : normalisasi
# perampokan : ampo
# shoplifting : shoplifting
# alasan : alas
# woke : woke
# culture : culture
# melawan : lawan
# peraturan : atur
# didak : didak
# jateng : jateng
# terlarang : larang
# tuk : tuk
# produksi : produksi
# jualan : jual
# petasan : petas
# sejenisnya : jenis
# su : su
# sendernya : sender
# tertarik : tarik
# dideketin : dideketin
# penganut : anut
# komen : komen
# sepert : sepert
# salah : salah
# acuan : acu
# jurnalisme : jurnalisme
# lurus : lurus
# terjebak : jebak
# politik : politik
# keberpihakan : pihak
# muhaimin : muhaimin
# iskandar : iskandar
# puan : puan
# mahal : mahal
# erick : erick
# thohir : thohir
# prabowo : prabowo
# subianto : subianto
# anies : anies
# baswedan : baswedan
# unggul : unggul
# gubernur : gubernur
# jawa : jawa
# segender : gender
# beda : beda
# miris : miris
# sekali : sekali
# kadal gurun : kadal gurun
# gambar : gambar
# akimu : aki
# istiqomah : istiqomah
# roger : roger
# danuarta : danuarta
# cut : cut
# meyriska : meyriska
# ajarkan : ajar
# anak : anak
# ali : ali
# catatan : catat
# hitam : hitam
# wadas : wadas
# kendeng : kendeng
# saksi : saksi
# hidup : hidup
# slogan : slogan
# tuan : tuan
# ku : ku
# omong : omong
# kosong : kosong
# tidak : tidak
# mh : mh
# bnyak : bnyak
# malas : malas
# aje : aje
# ngider : ngider
# nyari : nyari
# jajanan : jajan
# aye : aye
# bogor : bogor
# lupa : lupa
# yak : yak
# visit : visit
# filled : filled
# dengan : dengan
# happiness : happiness
# pranowos : pranowos
# to : to
# the : the
# orphanage : orphanage
# where : where
# talented : talented
# resident : resident
# mala : mala
# receives : receives
# laptop : laptop
# gift : gift
# from : from
# lttd : lttd
# border : border
# px : px
# solid : solid
# baru : baru
# msodataplacementsamecellgt : msodataplacementsamecellgt
# sender : sender
# bingung : bingung
# nanya : nanya
# base : base
# kristen : kristen
# pendetanya : pendeta
# islam : islam
# ustadnya : ustad
# masingmasing : masingmasing
# pemuka : muka
# berharap : harap
# modelan : model
# begini : begini
# hadeh : hadeh
# aneh : aneh
# intinya : inti
# susah : susah
# ijin : ijin
# ibadah : ibadah
# mayoritassederhana : mayoritassederhana
# wahh : wahh
# mantappp : mantappp
# dicapreskan : dicapreskan
# menguntungkan : untung
# capres : capres
# suara : suara
# jokowi : jokowi
# masuk : masuk
# mendukung : dukung
# heheheh : heheheh
# coba : coba
# nama : nama
# maksud : maksud
# setidaknya : tidak
# astaga : astaga
# serangan : serang
# krl : krl
# terus : terus
# diinjak : injak
# diremehkan : remeh
# harga : harga
# gsp : gsp
# ngegas : ngegas
# ag : ag
# hukuman : hukum
# maximal : maximal
# rekaman : rekam
# aktivitas : aktivitas
# diumbar : umbar
# seindonesia : indonesia
# raya : raya
# animeind : animeind
# update : update
# terbaru : baru
# genshin : genshin
# impact : impact
# perbincangan : bincang
# pemain : main
# cerita : cerita
# hadir : hadir
# gamenya : gamenya
# dis : dis
# meta : meta
# subekti : subekti
# pemberian : beri
# insentif : insentif
# pemprov : pemprov
# kpada : kpada
# sbagai : sbagai
# pengajar : ajar
# budha : budha
# patut : patut
# alquds : alquds
# internasional : internasional
# argumen : argumen
# zionis : zionis
# membenarkan : benar
# penjajahan : jajah
# israel : israel
# palestina : palestina
# dasar : dasar
# akal : akal
# sehat : sehat
# legal : legal
# sejarah : sejarah
# malcolm : malcolm
# kampungan : kampung
# kalah : kalah
# debat : debat
# bawa : bawa
# thread : thread
# bagus : bagus
# misteri : misteri
# menerima : terima
# tuhan : tuhan
# menerimanya : terima
# mengajarkan : ajar
# sibuk : sibuk
# berteduh : teduh
# membentengi : benteng
# darinya : dari
# bersyukur : syukur
# menulis : tulis
# bahasa : bahasa
# indonesia : indonesia
# dimana : mana
# multitafsir : multitafsir
# universal : universal
# kepercayaan : percaya
# dianut : anut
# kamu : kamu
# nyaman : nyaman
# seneng : neng
# sengsara : sengsara
# diuji : uji
# kayak : kayak
# diombangambing : diombangambing
# pastiin : pastiin
# kuat : kuat
# sampe : sampe
# pindah : pindah
# nemu : nemu
# crush : crush
# muslim : muslim
# eh : eh
# goyah : goyah
# pondasi : pondasi
# kokoh : kokoh
# tanyain : tanyain
# sama : sama
# nder : nder
# percaya : percaya
# melaporkan : lapor
# bersangkutan : sangkut
# langsung : langsung
# kalau : kalau
# berhak : hak
# orangtuanya : orangtuanya
# nikah : nikah
# pasangan : pasang
# hak : hak
# syarat : syarat
# lapor : lapor
# alat : alat
# bukti : bukti
# tinggalin : tinggalin
# agamamu : agama
# kristiani : kristiani
# tapi : tapi
# tekad : tekad
# bulat : bulat
# lagi : lagi
# mom : mom
# is : is
# housewife : housewife
# thats : thats
# intersectionality : intersectionality
# of : of
# this : this
# problem : problem
# parents : parents
# esp : esp
# please : please
# cari : cari
# ilmu : ilmu
# how : how
# handle : handle
# typoultra : typoultra
# konservatif : konservatif
# india : india
# istarl : istarl
# dikuasai : asai
# kelompok : kelompok
# ultra : ultra
# sangat : sangat
# jahat : jahat
# minoritas : minoritas
# afganistan : afganistan
# ayo : ayo
# rukun : rukun
# menyebut : sebut
# diusung : usung
# pdip : pdip
# fx : fx
# hadi : had
# rudyatmo : rudyatmo
# mengelak : elak
# ngomong : ngomong
# diwawancarai : wawancara
# gmna : gmna
# donk : donk
# konteks : konteks
# lihat : lihat
# videonya : video
# tau : tau
# kejadian : jadi
# februari : februari
# kafirun : kafirun
# deva : deva
# anomali : anomali
# eri : eri
# diajengemy : diajengemy
# wijoyo : wijoyo
# christing : christing
# gerai : gerai
# minimarket : minimarket
# menawarkan : tawar
# minuman : minum
# dingin : dingin
# dalam : dalam
# display : display
# menarik : tarik
# membatalkan : batal
# puasa : puasa
# diobrak : diobrak
# abrik : abrik
# laskar : laskar
# sudah : sudah
# bayar : bayar
# jizyah : jizyah
# warung : warung
# ditutup : tutup
# thecoffee : thecoffee
# iya : iya
# baca : baca
# hasil : hasil
# risetnya : riset
# ford : ford
# foundation : foundation
# buku : buku
# tentang : tentang
# paedo : paedo
# bali : bal
# berkedok : kedok
# adopsi : adopsi
# bah : bah
# dikenal : kenal
# juga : juga
# statutory : statutory
# rape : rape
# hubungan : hubung
# bisa : bisa
# memenuhi : penuh
# perlindungan : lindung
# bebas : bebas
# disambut : sambut
# pengagumnya : kagum
# unik : unik
# heran : heran
# dimanapun : mana
# tempatnya : tempat
# mayoritas : mayoritas
# otomatis : otomatis
# show : show
# hahaha : hahaha
# ingett : ingett
# bgtt : bgtt
# temen : temen
# ngelakuin : ngelakuin
# sidang : sidang
# guru : guru
# terluka : luka
# kafir : kafir
# mengakui : aku
# syahadat : syahadat
# pendukung : dukung
# medsos : medsos
# catut : catut
# membodohi : bodoh
# masyarakat : masyarakat
# awam : awam
# membantu : bantu
# dianggap : anggap
# berpahala : pahala
# membela : bela
# melancarkan : lancar
# id : id
# topeng : topeng
# networks : networks
# fachry : fachry
# anakkolong : anakkolong
# morafia : morafia
# tikadrun : tikadrun
# chotimah : chotimah
# statemen : statemen
# bloon : bloon
# kayaknya : kayak
# kesalahan : salah
# asusila : asusila
# kentara : kentara
# ente : ente
# ateis : ateis
# atau : atau
# anti : anti
# agnostik : agnostik
# klaim : klaim
# ane : ane
# standing : standing
# rendahkah : rendah
# berpikiror : berpikiror
# putusannya : putus
# penggadilan : penggadilan
# dinyatakan : nyata
# bersalah : salah
# boyolali : boyolali
# presiden : presiden
# joko : joko
# widodo : widodo
# mengecek : ecek
# bahan : bahan
# pokok : pokok
# pasar : pasar
# legi : legi
# jalan : jalan
# letjen : letjen
# parman : parman
# kota : kota
# solo : solo
# dalih : dalih
# berperilaku : perilaku
# biadab : biadab
# korsel : korsel
# cantik : cantik
# idol : idol
# bullying : bullying
# abiiiisss : abiiiisss
# pokoknya : pokok
# begitu : begitu
# lha : lha
# berpuasa : puasa
# makan : makan
# resto : resto
# memangnya : memang
# bejat : bejat
# pengasuh : asuh
# ponpes : ponpes
# cabuli : cabul
# santriwati : santriwati
# kapolda : kapolda
# irjen : irjen
# pol : pol
# ahmad : ahmad
# luthfi : luthfi
# me : me
# berusaha : usaha
# manipulasieksploitasi : manipulasieksploitasi
# dilabelin : dilabelin
# peyoratif : peyoratif
# sjw : sjw
# simpleton : simpleton
# ed : ed
# kuasa : kuasa
# pengampunan : ampun
# dibawah : bawah
# yang di pertuan agong : yang di tuan agong
# nafikan : nafi
# perkara : perkara
# berniat : niat
# jawabannya : jawab
# pelajari : ajar
# dari : dari
# sumbernya : sumber
# kitab : kitab
# sucinya : suci
# modal : modal
# hati : hati
# ikhlas : ikhlas
# terbuka : buka
# nnt : nnt
# dapat : dapat
# memang : memang
# pencarian : cari
# proses : proses
# berpikir : pikir
# salat : salat
# tarawih : tarawih
# masjid : masjid
# syekh : syekh
# al : al
# zayed : zayed
# amatan : amat
# berpengaruh : pengaruh
# masak : masak
# nolak : nolak
# elektabilitas : elektabilitas
# turun : turun
# emang : emang
# pemilu : milu
# tel : tel
# aviv : aviv
# pemerintah : perintah
# zionist : zionist
# inzaghi : inzaghi
# ash : ash
# kepribadian : pribadi
# berbeda : beda
# isi : isi
# media : media
# sosial : sosial
# kataku : kata
# lebih baik : lebih baik
# akunnya : akun
# pribadi : pribadi
# dakwah : dakwah
# naaah : naaah
# depanku : depan
# ya : ya
# peradilan : adil
# diatur : atur
# menutup : tutup
# mata : mata
# bocah : bocah
# sewa : sewa
# kamar : kamar
# hotel : hotel
# melati : melati
# kegiatan : giat
# seks : seks
# digrebek : digrebek
# mengaku : aku
# melakukan : laku
# takut : takut
# ketahuan : tahu
# orangtua : orangtua
# menikah : meni
# wanita : wanita
# eropa : eropa
# ketimbang : ketimbang
# pergaulan : gaul
# disebabkan : sebab
# sekolahhidup : sekolahhidup
# dibesarkan : besar
# lingkungan : lingkung
# gua : gua
# pendahulu : dahulu
# penyempurnaan : sempurna
# deketin : deketin
# allah : allah
# sok : sok
# berdoa : doa
# semoga : moga
# revert : revert
# innalillahi : innalillahi
# ngerti : ngerti
# komennya : komennya
# mereka : mereka
# pada : pada
# histeris : histeris
# jebakan : jebak
# biarlah : biar
# diurus : urus
# jamaahnya : jamaah
# bantuan : bantu
# adl : adl
# trigger : trigger
# mu : mu
# pagi : pagi
# abang : abang
# jago : jago
# wkwkwkw : wkwkwkw
# aria : aria
# arbana : arbana
# kristi : kristi
# ca : ca
# kishe : kishe
# thene : thene
# ti : ti
# vajzat : vajzat
# jane : jane
# objekt : objekt
# jo : jo
# sthashe : sthashe
# vetem : vetem
# po : po
# mendampingi : damping
# berkunjung : kunjung
# tradisional : tradisional
# am : am
# triasari : triasari
# kawan : kawan
# suku : suku
# memberi : beri
# saran : saran
# istri : istri
# betisnya : betis
# gede : gede
# betis : betis
# pekerja : kerja
# lakilaki : lakilaki
# mau apa : mau apa
# kumpul-kumpul : kumpul
# gegitaran : gegitaran
# diwarung : warung
# misoginis : misoginis
# objektifikasi : objektifikasi
# perempuan : perempuan
# wajar : wajar
# contohnya : contoh
# ket : ket
# kire : kire
# pki : pki
# dibumi : bumi
# pertiwi : pertiwi
# sdah : sdah
# lenyap : lenyap
# gentayangan : gentayang
# buktinya : bukti
# suka : suka
# ataw : ataw
# kroni : kroni
# diluar : luar
# pakai : pakai
# logika : logika
# baju : baju
# etika : etika
# berpakaian : pakai
# lebaran : lebaran
# nakula : nakula
# geram : geram
# marah : marah
# mencabuli : cabul
# atasan : atas
# dipecat : pecat
# bentuk : bentuk
# oohhh : oohhh
# mds : mds
# bohong : bohong
# tuduhan : tuduh
# sedalam : dalam
# mendalami : dalam
# kokok : kokok
# bubar : bubar
# kuatkan : kuat
# sholat : sholat
# bole : bole
# khilaftergoda : khilaftergoda
# nonkonsensual : nonkonsensual
# otak : otak
# dibajak : bajak
# selangkangan : selangkang
# kemungkinanny : kemungkinanny
# maraknya : marak
# batang : batang
# speak : speak
# kebaya : kebaya
# milik : milik
# budaya : budaya
# pegawai : pegawai
# sakit : sakit
# penetapan : tetap
# tersangka : sangka
# skip : skip
# seh : seh
# translate : translate
# sono : sono
# misogini : misogini
# patriarki : patriark
# speechnya : speechnya
# pemenang : menang
# oscar : oscar
# dicut : cut
# pas : pas
# women : women
# empower : empower
# denial : denial
# napa : napa
# aaa : aaa
# ne : ne
# rregull : rregull
# tna : tna
# falesh : falesh
# shume : shume
# qe : qe
# te : te
# shqetesuam : shqetesuam
# fz : fz
# politikus : politikus
# partai : partai
# bersuara : suara
# islamofobia : islamofobia
# ditembak : tembak
# giniujungnya : giniujungnya
# densus : densus
# dibubarkan : bubar
# statement : statement
# tk : tk
# puas : puas
# ii : ii
# individu : individu
# tolong : tolong
# libatkan : libat
# kaum : kaum
# negeri : negeri
# bla : bla
# bleh : bleh
# ap : ap
# pergi : pergi
# hadap : hadap
# la : la
# bara : bara
# uc : uc
# ja : ja
# brani : brani
# ckp : ckp
# karyanya : karya
# murakami : murakami
# karena : karena
# dibuat : buat
# penasaran : penasaran
# ending : ending
# terlepas : lepas
# menghadirkan : hadir
# objek : objek
# smua : smua
# prtama : prtama
# kafka : kafka
# on : on
# shore : shore
# situ : situ
# karya : karya
# murkami : murkami
# lain : lain
# udien : udien
# tindakan : tindak
# batas : batas
# bertentangan : tentang
# ajaran : ajar
# wkwkwksejak : wkwkwksejak
# imigran : imigran
# dibaptis : baptis
# judul : judul
# jalang : jalang
# memberitahu : memberitahu
# dandy : dandy
# bahwa : bahwa
# dia : dia
# telah : telah
# molested : molested
# oleh : oleh
# david : david
# dugaan : duga
# berinisial : inisial
# konfirmasi : konfirmasi
# praktek : praktek
# tantric : tantric
# buddhism : buddhism
# komenlah : komenlah
# ritual : ritual
# aksi : aksi
# seksua : seksua
# oh : oh
# isunya : isu
# penghinaan : hina
# perdana menteri : perdana menteri
# lembaga : lembaga
# isu : isu
# kuburan : kubur
# muncul : muncul
# victim : victim
# blamers : blamers
# rep : rep
# diatas : atas
# padahal : padahal
# mari : mari
# berlomba : lomba
# mengembangkan : kembang
# menghambat : hambat
# aplg : aplg
# mempersulit : sulit
# follawers : follawers
# wajib : wajib
# paham : paham
# memviralkan : memviralkan
# kejahatan : jahat
# dituntut : tuntut
# danatau : danatau
# pencemaran : cemar
# ba : ba
# mobil : mobil
# bareng : bareng
# jan : jan
# etes : etes
# surakarta : surakarta
# beliau : beliau
# berdua : dua
# sema : sema
# besepah : besepah
# drp : drp
# tucuma : tucuma
# ramai : ramai
# pandai : pandai
# tulisan : tulis
# kelas : kelas
# pidana : pidana
# saya : saya
# kadang : kadang
# tahu : tahu
# pacar : pacar
# usia : usia
# pacaran : pacar
# sebagai : bagai
# ada : ada
# semangat : semangat
# tidaak : tidaak
# meliala : meliala
# bofoh : bofoh
# manusia : manusia
# ngoceh : ngoceh
# kaya : kaya
# burung : burung
# membe : membe
# sumatera : sumatera
# utara : utara
# bersilaturahmi : silaturahmi
# memperkenalkan : kenal
# sosok : sosok
# pilih : pilih
# terminologi : terminologi
# diem : diem
# ribut : ribut
# urusan : urus
# sndiri : sndiri
# dewasa : dewasa
# ditanyain : ditanyain
# disosmed : disosmed
# karna : karna
# han : han
# dicicipi : cicip
# diaraktrus : diaraktrus
# nyicipinya : nyicipinya
# pura : pura
# sucisumbar : sucisumbar
# salahsatu : salahsatu
# sarangnya : sarang
# kadrunpersis : kadrunpersis
# malinkundang : malinkundang
# kandungnya : kandung
# cicipi : cicip
# jugaparahhh : jugaparahhh
# ketoknya : ketok
# gerombolan : gerombol
# panggung : panggung
# loossss : loossss
# firly : firly
# gaassskkkeeeennnnn : gaassskkkeeeennnnn
# formula : formula
# menyerangberarti : menyerangberarti
# tolonglah : tolong
# fakta : fakta
# belain : bain
# ngenormalize : ngenormalize
# ancaman : ancam
# dibil : dibil
# hrs : hrs
# firman : firman
# brooo : brooo
# bagaimana : bagaimana
# mencintai : cinta
# ahli : ahli
# teologia : teologia
# umat : umat
# bilang : bilang
# membingungkan : bingung
# byk : byk
# kontradiksi : kontradiksi
# aalona : aalona
# negara : negara
# suci : suci
# dunia : dunia
# kejelasan : jelas
# menghukum : hukum
# berb : berb
# era : era
# admin : admin
# penistaan : nista
# doain : doain
# sehatsehat : sehatsehat
# yesus : yesus
# kristus : kristus
# penguasa : kuasa
# mengasihi : asih
# marm : marm
# bacaan : baca
# banyak omong : banyak omong
# berbelit belit : belit belit
# menjelaskan : jelas
# sisi : sisi
# edukasi : edukasi
# asli : asli
# kesel : kesel
# persetan : persetan
# banget : banget
# kitchen : kitchen
# ngomong-ngomong : ngomong-ngomong
# kepala : kepala
# chefmu : chefmu
# dilaporkan : lapor
# memakan : makan
# selamjutnya : selamjutnya
# memotong : potong
# buahku : buah
# becanda : becanda
# menjurus : jurus
# cebong : cebong
# radikal : radikal
# beraksi : aksi
# moral : moral
# adab : adab
# menelanjangi : telanjang
# pengunjung : unjung
# cafe : cafe
# didiamka : didiamka
# calm : calm
# logikanya : logika
# somplak : somplak
# china : china
# rampas : rampas
# kedaulatan : daulat
# nkri : nkri
# gagap : gagap
# dadaku : dada
# sllapalagi : sllapalagi
# rebahan : rebah
# bersender : sender
# beber : beber
# percakapannya : cakap
# gabung : gabung
# koalisi : koalisi
# sikat : sikat
# polda : polda
# kasih : kasih
# ampun : ampun
# predator : predator
# lampung : lampung
# pelabuhan : labuh
# merak : merak
# lucas : lucas
# akaza : akaza
# ep : ep
# emosi : emosi
# disembunyikan : sembunyi
# pemerkosaan : perkosa
# belasan : bas
# santri : santri
# ras : ras
# ditakuti : takut
# phobia : phobia
# akut : akut
# berurat : urat
# berakar : akar
# tanggapan : tanggap
# mahfud : mahfud
# md : md
# kabar : kabar
# wacana : wacana
# cawapres : cawapres
# mbaksri : mbaksri
# eks : eks
# hti : hti
# fpi : fpi
# berbuat : buat
# onar : onar
# april : april
# kemarin : kemarin
# ribu : ribu
# yahudi : yahudi
# tembok : tembok
# ratapan : ratap
# aqsa : aqsa
# andaikan : andai
# khilafah : khilafah
# berkuasa : kuasa
# bangun : bangun
# berdekatan : dekat
# berubah : ubah
# berimbang : imbang
# ganti : ganti
# malesnya : malesnya
# daftar : daftar
# kakak : kakak
# ktp : ktp
# qu : qu
# tahunan : tahun
# assalamualaikum : assalamualaikum
# simak : simak
# ustadz : ustadz
# mokoginta : mokoginta
# momen : momen
# shalat : shalat
# sheikh : sheikh
# kunjungannya : kunjung
# didampingi : damping
# memakai : pakai
# selara : selara
# setali : setal
# uang : uang
# menuntut : tuntut
# laksanakan : laksana
# kewajiban : wajib
# bengis : bengis
# ab : ab
# kunjungi : kunjung
# selo : selo
# antusias : antusias
# pedagang : dagang
# disana : sana
# batalnya : batal
# pildun : pildun
# ditunggangi : tunggang
# lawan : lawan
# unk : unk
# mengha : mengha
# barat : barat
# daring : daring
# anakanak : anakanak
# public : public
# figure : figure
# kerap : kerap
# diobjektifikasi : diobjektifikasi
# de : de
# direnungin : direnungin
# dimata : mata
# data : data
# teh : teh
# abdi : abdi
# mah : mah
# resep : resep
# ningali : ningali
# kejang : kejang
# kasurupan : kasurupan
# siga : siga
# mabuk : mabuk
# kecubung : kecubung
# mayan : mayan
# hiburan : hibur
# putra : putra
# putri : putri
# bangsa : bangsa
# tanah : tanah
# air : air
# merasakan : rasa
# pertiw : pertiw
# sinting : sinting
# sangean : sangean
# berduit : duit
# ekstremis : ekstremis
# kekerasan : keras
# percobaan : coba
# pembunuhan : bunuh
# urus : urus
# kau : kau
# masih : masih
# gereja : gereja
# disegeldipersulit : disegeldipersulit
# pembangunan : bangun
# tmpt : tmpt
# otk : otk
# dipake : dipake
# urusin : urusin
# bungkam : bungkam
# news : news
# dukung : dukung
# gus : gus
# yazid : yazid
# didatangi : datang
# tim : tim
# ganjarpranowo : ganjarpranowo
# penyimpangan : simpang
# diperberat : berat
# efek : efek
# jera : jera
# polri : polri
# halo : halo
# macem : macem
# sanggup : sanggup
# tangani : tangan
# republik indonesia : republik indonesia
# idofc : idofc
# ter : ter
# ulama : ulama
# gitian : gitian
# telusuri : telusur
# anjing : anjing
# terpapar : papar
# patters : patters
# bising : bising
# identitas elektronik : identitas elektronik
# minimnya : minim
# literasi : literasi
# penuturan : tutur
# bayangkan : bayang
# kanakkanak : kanakkanak
# kemiskinan : miskin
# sahaja : sahaja
# miskin : miskin
# harta : harta
# pendedahan : dedah
# kesudahan : sudah
# dibantu : bantu
# angkat : angkat
# keterlibatan : libat
# berdasarkan : dasar
# tud : tud
# tersinggung : singgung
# keselamatan : selamat
# dala : dala
# hahahahaha : hahahahaha
# kebenaran : benar
# keadilan : adil
# berhubungan : hubung
# sentimen : sentimen
# peka : peka
# penindasan : tindas
# samawi : samawi
# part : part
# deh : deh
# ajang : ajang
# war : war
# manfaat : manfaat
# menurutku : turut
# dikedua : dua
# postingan : postingan
# beropini : opini
# teolgi : teolgi
# menurutnya : turut
# satunya : satu
# menyoroti : sorot
# nabi : nabi
# muhammad : muhammad
# saw : saw
# diriwayatkan : riwayat
# aisyah : aisyah
# ra : ra
# usianya : usia
# tahun : tahun
# wktu : wktu
# wich : wich
# fine : fine
# kuhilang : hilang
# menang : menang
# dipanggil : panggil
# pembelaan : bela
# ayah : ayah
# putusan : putus
# pemidanaan : pidana
# ditemukan : temu
# kronologi : kronologi
# hakim : hakim
# jadiin : jadiin
# bang : bang
# kok : kok
# be : be
# ampel : ampel
# peran : peran
# zon : zon
# harapkan : harap
# berjalan : jalan
# petakilan : petakilan
# om : om
# one : one
# muka : muka
# berpikiran : pikir
# kontroversial : kontroversial
# menfess : menfess
# bahas : bahas
# jeno : jeno
# menganut : anut
# apus : apus
# beragamaga : beragamaga
# mempengaruhi : pengaruh
# kehidupan : hidup
# tuanya : tua
# sita : sita
# gadget : gadget
# anaknya : anak
# jaga : jaga
# ketikan : keti
# pemeluk : peluk
# sayang : sayang
# kehilangan : hilang
# saudara : saudara
# seagama : agama
# surga : surga
# pendukungnya : dukung
# lansung : lansung
# gruduk : gruduk
# kpk : kpk
# teriak : teriak
# dzolim : dzolim
# mang : mang
# edan : edan
# taxi : taxi
# driver : driver
# case : case
# arc : arc
# lookism : lookism
# sesat : sesat
# gunain : gunain
# jualbeli : jualbeli
# appartement : appartement
# club : club
# narkotika : narkotika
# final : final
# black : black
# sun : sun
# sampanye : sampanye
# diangkutangkut : diangkutangkut
# vivi : vivi
# awokwokwok : awokwokwok
# jiah : jiah
# tindak : tindak
# tanduknya : tanduk
# bunglon : bunglon
# gagal : gagal
# solusi : solusi
# beo : beo
# algoritma : algoritma
# instagram : instagram
# reels : reels
# abis : abis
# vidio : vidio
# mantep : mantep
# scroll : scroll
# ceramah : ceramah
# ngurusi : ngurusi
# pezina : zina
# pesan : pesan
# mesum : mesum
# puja : puja
# imam : imam
# fahim : fahim
# mawardikyai : mawardikyai
# cabul : cabul
# jember : jember
# anggap : anggap
# wwoiii : wwoiii
# ngap : ngap
# nafaskuu : nafaskuu
# twpelecehan : twpelecehan
# twitter : twitter
# do : do
# your : your
# magic : magic
# akun : akun
# jarang : jarang
# aktif : aktif
# tap : tap
# dibalik : balik
# hidayah : hidayah
# yes : yes
# tidur : tidur
# timeline : timeline
# isinya : isi
# omom : omom
# tua : tua
# bangkotan : bangkot
# obsessed : obsessed
# histori : histori
# melakukan perundungan : laku rundung
# sd : sd
# sadar : sadar
# mengeluarkan : keluar
# sepupu : sepupu
# uwaku : uwaku
# lampiasin : lampiasin
# berbalut : balut
# khan : khan
# hujatan : hujat
# jerat : jerat
# cukong : cukong
# disentuh : sentuh
# hehehe : hehehe
# geng : geng
# pengikut : ikut
# amirulruslam : amirulruslam
# thexguy : thexguy
# pu : pu
# jamal : jamal
# zizi : zizi
# syamim : syamim
# mereng : mereng
# belaka : belaka
# menunggang : tunggang
# pon : pon
# point : point
# kelaut : laut
# hujah : hujah
# disokong : sokong
# lgbt : lgbt
# syariat : syariat
# ongko : ongko
# perhatian : perhati
# investor : investor
# pabrikusaha : pabrikusaha
# enak : enak
# nyalahin : nyalahin
# versinya : versi
# pakar : pakar
# keuangan : uang
# kebanyakan : banyak
# bacot : bacot
# mikir : mikir
# dipikir : pikir
# pikir : pikir
# intensi : intensi
# janga : janga
# pemikiran : pikir
# menyingkapi : singkap
# senonoh : senonoh
# kelakuan : laku
# iblis : iblis
# bertopengksn : bertopengksn
# milih : milih
# ngeklaim : ngeklaim
# mengesankan : kesan
# olah : olah
# calon : calon
# agamis : agam
# nonton : nonton
# porno : porno
# haram : haram
# pilihan : pilih
# survei : survei
# sblm : sblm
# vaksin : vaksin
# pap : pap
# smear : smear
# scr : scr
# harapan : harap
# doa : doa
# terbaik : baik
# tokoh : tokoh
# ngaji : ngaji
# sumenep : sumenep
# madura : madura
# pastin : pastin
# pemuda : pemuda
# hadiri : hadir
# peringatan : ingat
# humanitarian : humanitarian
# day : day
# acara : acara
# digelar : gelar
# swisbel : swisbel
# provinsi : provinsi
# tujuan : tuju
# mencari : cari
# keridhoan : keridhoan
# taala : taala
# judulnya : judul
# bawabawa : bawabawa
# min : min
# nyebutkan : nyebutkan
# bhabinkamtibmas : bhabinkamtibmas
# desa : desa
# pancawati : pancawati
# aiptu : aiptu
# wawan : wawan
# dulhakim : dulhakim
# melaksanakan : laksana
# anjangsanasilaturrahmi : anjangsanasilaturrahmi
# kamtibmas : kamtibmas
# kp : kp
# leweung : leweung
# lalarang : lalarang
# bpk : bpk
# ustad : ustad
# wahab : wahab
# tangkil : tangkil
# kec : kec
# caringin : caringin
# pedo : pedo
# dijustifikasi : justifikasi
# dibelain : bain
# dalil : dalil
# puji : puji
# mikirnya : mikirnya
# keren : keren
# bat : bat
# ore : ore
# celana : celana
# robek : robek
# potong : potong
# top : top
# aslinya : asli
# kekurangan : kurang
# indeed : indeed
# askrl : askrl
# goa : goa
# galak : galak
# jaket : jaket
# peluru : peluru
# durling : durling
# sarling : sarling
# bupati : bupati
# yuni : yuni
# berasumsi : asumsi
# ambil : ambil
# kesempatan : sempat
# ditelanjangi : telanjang
# buka : buka
# ngarak : ngarak
# gendong : gendong
# gulingin : gulingin
# ikutan : ikut
# megang : megang
# bersembunyi : sembunyi
# karoke : karoke
# bangga : bangga
# bilangin : bilangin
# sohibmu : sohib
# sewot : sewot
# nyerang : nyerang
# lakukan : laku
# perbolehkan : boleh
# vid : vid
# persekusi : persekusi
# sumbar : sumbar
# fanatisme : fanatisme
# arb : arb
# ateismenya : ateisme
# meningkat : tingkat
# pesat : pesat
# berulang : ulang
# kali : kali
# terlibat : libat
# khilaf : khilaf
# tanggungjawab : tanggungjawab
# based : based
# diorang : orang
# isteri : isteri
# ihsan : ihsan
# suami : suami
# sunat : sunat
# penghayatan : hayat
# memilih : pilih
# bola : bola
# lantas : lantas
# membiarkan : biar
# tan : tan
# malaka : malaka
# nasib : nasib
# buruh : buruh
# perkebunan : kebun
# kolonial : kolonial
# belanda : belanda
# meninggal : tinggal
# habis : habis
# kontraknya : kontrak
# digugat : gugat
# arab : arab
# islamnya : islam
# fantasi : fantasi
# gambaran : gambar
# mental : mental
# pola : pola
# seksualitas : seksualitas
# meningkatkan : tingkat
# hasrat : hasrat
# singkatnya : singkat
# bhw : bhw
# terbantahkan : bantah
# trauma : trauma
# dirasakan : rasa
# anggota : anggota
# parah : parah
# apa : apa
# film porno : film porno
# dulu : dulu
# gerak : gerak
# diperhatikan : perhati
# telanjang : telanjang
# demo : demo
# bohirnya : bohirnya
# yakali : yakali
# huruf : huruf
# besarnya : besar
# barangsiapa : barangsiapa
# membenci : benci
# kelelahan : lelah
# melayani : layan
# makhluk : makhluk
# ibnul : ibnul
# qayyim : qayyim
# rahimahullah : rahimahullah
# sampesampe : sampesampe
# kuliah : kuliah
# anda : anda
# eps : eps
# ramadhan : ramadhan
# butuh : butuh
# hibur : hibur
# oiya : oiya
# dzawin : dzawin
# sekilas : kilas
# gebetan : gebetan
# selera : selera
# psikopat : psikopat
# omongan : omong
# ps : ps
# telaaaaat : telaaaaat
# mimpin : mimpin
# sekian : sekian
# elemen : elemen
# rusak : rusak
# lapisan : lapis
# ekonomi : ekonomi
# tercipta : cipta
# jurus : jurus
# sakti : sakti
# kepentingan : penting
# siapaaapreet : siapaaapreet
# kritik : kritik
# dikit : dikit
# kocak : kocak
# kaget : kaget
# survey : survey
# yaman : yaman
# pemberi : beri
# hibah : hibah
# pegangsaan : gangsa
# timur : timur
# no : no
# saudagar : saudagar
# hadramaut : hadramaut
# ber : ber
# wkwkwkwkwk : wkwkwkwkwk
# buzerrp : buzerrp
# sampah : sampah
# ahherat : ahherat
# tukang : tukang
# palsu : palsu
# penista : nista
# penyjilat : penyjilat
# pengangguran : anggur
# pecinta : cinta
# kulup : kulup
# jinah : jah
# bodok : bodok
# memfitnh : memfitnh
# dungu : dungu
# dubur : dubur
# fifa : fifa
# menpan : menpan
# rb : rb
# regulasi : regulasi
# batasan : batas
# pns : pns
# zie : zie
# hm : hm
# maaf : maaf
# mencelah : celah
# tkla : tkla
# sngt : sngt
# bab : bab
# namanya : nama
# ujian : uji
# hambanya : hamba
# nafsu : nafsu
# title : title
# jihad : jihad
# pendosa : dosa
# bertaubat : taubat
# akrab : akrab
# lengket : lengket
# mesranya : mesra
# malam : malam
# rasmi : rasmi
# fadzil : fadzil
# zzz : zzz
# fikir : fikir
# ucapan : ucap
# hasutan : hasut
# menyeru : seru
# intervensi : intervensi
# tujuanmu : tuju
# kehangatan : hangat
# protes : protes
# pembatalan : batal
# status : status
# piala : piala
# berbuntut : buntut
# amarah : amarah
# menolak : tolak
# kedatangan : datang
# timnas : timnas
# jiji : jiji
# demen : demen
# justifikasi : justifikasi
# alesan : alesan
# bercanda : canda
# kek : kek
# pecahin : pecahin
# palalu : palalu
# mesra : mesra
# mesraan : mesra
# merujuk : rujuk
# hub : hub
# sepi : sepi
# tertangkap : tangkap
# kak : kak
# katolik : katolik
# domba : domba
# tersesat : sesat
# neraka : neraka
# terima : terima
# hah : hah
# trainee : trainee
# grup : grup
# wih : wih
# knetz : knetz
# wkwkw : wkwkw
# tidak apa-apa : tidak apa
# papsmear : papsmear
# nunggu : nunggu
# gejala : gejala
# sbnr : sbnr
# pao : pao
# aktf : aktf
# rutin : rutin
# jenayah : jenayah
# ketetapan : tetap
# tarikh : tarikh
# rabu : rabu
# platform : platform
# live : live
# fb : fb
# page : page
# pejabat : jabat
# pulau : pulau
# pinangppwnpp : pinangppwnpp
# telanjangi : telanjang
# ntar : ntar
# embel : embel
# kelakuannya : laku
# kemaren : kemaren
# pilgub : pilgub
# dibawa : bawa
# santai : santai
# hubungannya : hubung
# kekuasaan : kuasa
# jabatan : jabat
# tata : tata
# solat : solat
# channel : channel
# adi : adi
# hidayat : hidayat
# semuaaaaaaanya : semuaaaaaaanya
# lengkap : lengkap
# cek : cek
# yt : yt
# gratiisss : gratiisss
# sahur : sahur
# tidurnya : tidur
# jam : jam
# an : an
# tep : tep
# hmm : hmm
# mampus : mampus
# penis : penis
# sakitnya : sakit
# pikirin : pikirin
# jonan : jonan
# tugas : tugas
# tangga : tangga
# malu : malu
# foto : foto
# profilenya : profilenya
# peci : peci
# gelarnya : gelar
# diangkut : angkut
# yasudah : yasudah
# menginterogasi : interogasi
# membuka : buka
# posko : posko
# pengaduan : adu
# melapor : lapor
# harap : harap
# pencabulan : cabul
# dihukum : hukum
# seberatnya : berat
# menyiarkan : siar
# publik : publik
# pengalaman : alam
# diangg : diangg
# preferensi : preferensi
# ideal : ideal
# fokus : fokus
# area : area
# dll : dll
# alhamdulilah : alhamdulilah
# analisan : analis
# coaching : coaching
# kecocokan : cocok
# klien : klien
# senang : senang
# laporannya : lapor
# selesai : selesai
# tweet : tweet
# pendapat : dapat
# bgmn : bgmn
# memuliakan : mulia
# ucapkan : ucap
# berseberangan : berangan
# sejalan : jalan
# sah : sah
# bongkar : bongkar
# polisi : polisi
# tni : tni
# papua : papua
# drun : drun
# tumpas : tumpas
# tujuannya : tuju
# mengalahkan : kalah
# ngelepas : ngelepas
# hes : hes
# deserved : deserved
# ngerasa : ngerasa
# worth : worth
# sia : sia
# fanatik : fanatik
# rendahin : rendahin
# ughtee : ughtee
# hijrah : hijrah
# faktanya : fakta
# dibanding : banding
# skandal : skandal
# narkoba : narkoba
# terrist : terrist
# abaikan : abai
# bhaiklah : bhaiklah
# munafik : munafik
# thanks : thanks
# mba : mba
# mudahkan : mudah
# rekomendasi : rekomendasi
# channels : channels
# bertemu : temu
# dai : dai
# berdakwah : dakwah
# kondisi : kondisi
# kuroi : roi
# jatuh : jatuh
# momojiri : momojiri
# gadis : gadis
# open : open
# bo : bo
# mengajak : ajak
# berpacaran : pacar
# bol : bol
# doctor : doctor
# langit : langit
# kelam : kelam
# kufah : kufah
# lautan : laut
# luka : luka
# duka : duka
# retak : retak
# memikul : pikul
# sedih : sedih
# pilu : pilu
# penekanan : tekan
# seggs : seggs
# lumrahnya : lumrah
# dialami : alami
# setuju : tuju
# mesti : mesti
# segamblang : gamblang
# sebenarnya : benar
# rupiah : rupiah
# denda : denda
# menghina : hina
# teros : ros
# heboh : heboh
# cuma : cuma
# gitu : gitu
# diberitakan : berita
# giliran : gilir
# getol : getol
# welcome : welcome
# Indonesia : indonesia
# hukumnya : hukum
# hs : hs
# bujukkan : bujuk
# laki : laki
# lakinya : laki
# ditindak : tindak
# terhadap : hadap
# perempuannya : perempuan
# bedanya : beda
# dapet : dapet
# sanksi : sanksi
# tambahan : tambah
# fisik : fisik
# disepelekan : sepele
# tidak ada : tidak ada
# bebasin : bebasin
# difasilitasi : fasilitas
# jiwa : jiwa
# sebenernya : sebenernya
# jaman : jaman
# wild : wild
# segitu : segitu
# samasama : samasama
# bugil : bugil
# sudahi : sudah
# kebisingan : bising
# beralasan : alas
# suaranya : suara
# diam : diam
# tidak tahu : tidak tahu
# duit : duit
# menyimpan : simpan
# alias : alias
# bajingan : bajing
# semua : semua
# og : og
# riskan : riskan
# menyerahkan : serah
# bari : bari
# manusiawi : manusiawi
# ngobrol : ngobrol
# frontal : frontal
# pegang : pegang
# menyentuh : sentuh
# run : run
# main : main
# tangan : tangan
# pasti : pasti
# sempet : sempet
# riset : riset
# tibet : tibet
# cium : cium
# mencium : cium
# bibirsekedar : bibirsekedar
# bersentuhan : sentuh
# hisap : hisap
# menghisap : menghisap
# lidah : lidah
# kenapa : kenapa
# wkwkk : wkwkk
# nyepelein : nyepelein
# kenal : kenal
# konsen : konsen
# pelindung : lindung
# wakanda : wakanda
# tugasnya : tugas
# cepet : cepet
# tembak : tembak
# bangsat : bangsat
# seberat : berat
# adminnya : adminnya
# kerjaan : kerja
# bawaan : bawa
# disalahin : disalahin
# ditambah : tambah
# sksul : sksul
# tgl : tgl
# maret : maret
# uda : uda
# duluan : duluan
# nglapor : nglapor
# berbau : bau
# ribet : ribet
# harusny : harusny
# delik : delik
# aduan : adu
# rugikan : rugi
# aturan : atur
# hp : hp
# rud : rud
# ketum : tum
# korbankan : korban
# periode : periode
# prestasinya : prestasi
# zero : zero
# prestasiminim : prestasiminim
# bingitz : bingitz
# mendingan : mending
# mbak : mbak
# hc : hc
# ssos : ssos
# demokrasi : demokrasi
# akalan : akal
# komunis : komunis
# pemerintahan : perintah
# kemajuan : maju
# cakeuuupppp : cakeuuupppp
# diadili : adil
# seadil : adil
# adilnya : adil
# dituduh : tuduh
# pantes : pantes
# dibuka : buka
# sex : sex
# recordnya : recordnya
# dibutuhkan : butuh
# dibocorkannya : bocor
# record : record
# dsrnya : dsrnya
# pikirannya : pikir
# kotor : kotor
# manada : manada
# maling : maling
# dbebasin : dbebasin
# sepele : sepele
# amet : amet
# ksian : ksi
# psti : psti
# perna : perna
# laporin : laporin
# bos : bos
# hr : hr
# jelasin : jelasin
# laporanmu : lapor
# cabut : cabut
# menoleransi : toleransi
# penuh : penuh
# bahaya : bahaya
# panca : panca
# get : get
# what : what
# you : you
# paid : paid
# tabu : tabu
# etis : etis
# dsb : dsb
# koma : koma
# berdaya : daya
# senggaknya : senggak
# dibunuh : bunuh
# dimutilasi : mutilasi
# ditipu : tipu
# dirampok : rampok
# diculik : culik
# dihilangkan : hilang
# keluarga : keluarga
# kepikiran : pikir
# nyariin : nyariin
# akuuuu : akuuuu
# ketemuan : ketemu
# asing : asing
# sejujurnya : jujur
# inih : inih
# digroomed : digroomed
# berkali : kali
# simple : simple
# groomers : groomers
# kebakaran : bakar
# jenggot : jenggot
# basis : basis
# ruangnya : ruang
# censorship : censorship
# duhkenang : duhkenang
# ugm : ugm
# alihalih : alihalih
# simpati : simpati
# dirujak : rujak
# lombok : lombok
# insider : insider
# diposisi : posisi
# normal : normal
# ngelewatin : ngelewatin
# fase : fase
# survive : survive
# putus : putus
# kontol : kontol
# tai : tai
# haduh : haduh
# saja : saja
# masalh : masalh
# but : but
# gwe : gwe
# stronk : stronk
# sumbu : sumbu
# pendek : pendek
# ngirimin : ngirimin
# maybank : maybank
# abraham : abraham
# samad : samad
# membocorkan : bocor
# pemeriksaan : periksa
# sprindik : sprindik
# terbukti : bukti
# ditetapkan : tetap
# gojlang : gojlang
# kitu : kitu
# kawanku : kawan
# overprotektif : overprotektif
# seminggu : minggu
# padan : padan
# beringat : ingat
# sikit : sikit
# benda : benda
# hero : hero
# menyebarkan : sebar
# fitnahsiap : fitnahsiap
# reza : reza
# rest : rest
# peace : peace
# penjara : penjara
# woy : woy
# dipegangpegang : dipegangpegang
# maen : maen
# ditidurin : ditidurin
# bool : bool
# ditusuk : tusuk
# keliatan : liat
# boti : bot
# problematik : problematik
# nyakitin : nyakitin
# saar : saar
# rijik : rijik
# dibui : bui
# preet : preet
# wkwkwkwk : wkwkwkwk
# habib : habib
# jumbo : jumbo
# cucu : cucu
# diusir : usir
# hoaxnya : hoaxnya
# orangorang : orangorang
# beragama : agama
# klakuannya : klakuannya
# loren : loren
# ngeles : ngeles
# rukiah : rukiah
# putusin : putusin
# tlol : tlol
# ngejar : ngejar
# pria : pria
# dirimu : diri
# ydah : ydah
# layak : layak
# bego : bego
# siih : siih
# red : red
# flag : flag
# tunangan : tunang
# manipulatif : manipulatif
# yailaaaa : yailaaaa
# apasi : apas
# sepak : sepak
# sepatutnya : patut
# je : je
# good : good
# rekening : rekening
# lookingga : lookingga
# alah : alah
# benci : benci
# giniin : giniin
# ditroll : ditroll
# mantan : mantan
# kaga : kaga
# danta : danta
# pisan : pis
# jelek : jelek
# samgat : samgat
# nge : nge
# halah : halah
# mayat : mayat
# opini : opini
# wkawkawka : wkawkawka
# pdhl : pdhl
# penganiayaan : aniaya
# mohon : mohon
# benerbener : benerbener
# menit : menit
# kereta : kereta
# imagine : imagine
# rush : rush
# enakkan : enak
# bnget : bnget
# ngeri : ngeri
# pacarnya : pacar
# samak : samak
# jahanam : jahanam
# cmn : cmn
# pgn : pgn
# menikmati : nikmat
# kasur : kasur
# inikenapa : inikenapa
# tb : tb
# info : info
# kelassssss : kelassssss
# fakkk : fakkk
# terangsang : rangsang
# dikasih : kasih
# bpkb : bpkb
# istilah : istilah
# nolong : nolong
# kejepit : jepit
# jaminan : jamin
# disita : sita
# dilelang : lelang
# peminjam : pinjam
# nunggak : nunggak
# hutangnya : hutang
# hutang : hutang
# macet : macet
# mimpi : mimpi
# tdr : tdr
# sfood : sfood
# yaallah : yaallah
# berisik : berisik
# ah : ah
# gabisa : gabisa
# filter : filter
# babi : babi
# monyettttttt : monyettttttt
# hewan : hewan
# ngeprint : ngeprint
# cokkkkk : cokkkkk
# burek : burek
# google : google
# tetep : tetep
# print : print
# bodo : bodo
# spoiler : spoiler
# dont : dont
# lie : lie
# hasibuan : hasibuan
# playing : playing
# membalikan : balik
# ko : ko
# bgtu : bgtu
# tra : tra
# banding : banding
# nnti : nnti
# wakwak : wakwak
# buta : buta
# proyek : proyek
# dikata : kata
# lubang : lubang
# sentuh : sentuh
# ak : ak
# colmek : colmek
# yaaa : yaaa
# anus : anus
# yohanes : yohanes
# berpestai : pesta
# pungsi : pungsi
# tugu : tugu
# bambu : bambu
# gajelas : gajelas
# monyed : monyed
# waras : waras
# lh : lh
# kan : kan
# inisial : inisial
# tuyul : tuyul
# perusahaan : usaha
# cape : cape
# capek : capek
# bangett : bangett
# lee : lee
# maksdnya : maksdnya
# flying : flying
# kisss : kisss
# salting : salting
# svshshgsga : svshshgsga
# chan : chan
# kasian : kasi
# digigit : gigit
# kutu : kutu
# samasekali : samasekali
# edu : edu
# dilakuin : dilakuin
# adek : adek
# kakakku : kakak
# lulus : lulus
# prepare : prepare
# married : married
# pelecehannya : leceh
# sekitaran : sekitar
# lbs : lbs
# apaaan : apaaan
# sga : sga
# dih : dih
# yaalah : yaalah
# apaa : apaa
# gemes : gemes
# bgttcdbshshhs : bgttcdbshshhs
# prim : prim
# bunting : bunting
# asmarakebiri : asmarakebiri
# wkwkwkwkwkwwkwkw : wkwkwkwkwkwwkwkw
# vikinisasi : vikinisasi
# terlambat : lambat
# ajg : ajg
# pasrah : pasrah
# matmit : matmit
# tol : tol
# cem : cem
# sebel : sebel
# yaudah : yaudah
# afk : afk
# kagak : kagak
# make : make
# wanwan : wanwan
# anjrittttttt : anjrittttttt
# hadehhh : hadehhh
# fakyu : fakyu
# aib : aib
# verbal : verbal
# pemaksaan : paksa
# gila : gila
# bisaan : bisa
# smpe : smpe
# kebawa : bawa
# rezim : rezim
# sial : sial
# ngosan : ngosan
# ketinggalan : tinggal
# ansori : ansori
# sajak : sajak
# tunggu : tunggu
# looks : looks
# terganteng : ganteng
# impian : impi
# diambil : ambil
# sat : sat
# internal : internal
# aspeknyatapi : aspeknyatapi
# laporan : lapor
# bro : bro
# pulakkkk : pulakkkk
# kecik : kecik
# najis : najis
# berat : berat
# tetiba : tetiba
# nampak : nampak
# adoiii : adoiii
# berasakan : rasa
# tukar : tukar
# zaman : zaman
# dsana : dsana
# dsini : dsini
# amrik : amrik
# cuman : cuman
# meronrong : meronrong
# bumi : bumi
# ye : ye
# dito : dito
# hidupku : hidup
# psikis : psikis
# melampaui : lampau
# lagu : lagu
# remix : remix
# gemboknya : gembok
# cupu : cupu
# basmi : basmi
# dn : dn
# misuh : misuh
# blok : blok
# diramain : diramain
# stan : stan
# ngungkapin : ngungkapin
# kekeselan : kesel
# norak : norak
# besok : besok
# cok : cok
# lomba : lomba
# osis : osis
# infonya : info
# harbi : harbi
# pemakan : makan
# takkan : tak
# mengerti : erti
# tidak perlu : tidak perlu
# berlagak : lagak
# mega : mega
# calonkan : calon
# tanda : tanda
# trah : trah
# sukarno : sukarno
# luntur : luntur
# suaminya : suami
# baikan : baik
# yo : yo
# nganyeli : nganyeli
# ancenn : ancenn
# disuruh : suruh
# ttdnya : ttdnya
# digital : digital
# ngotot : ngotot
# kampus : kampus
# nyuruh : nyuruh
# diputusin : diputusin
# tbtb : tbtb
# fitri : fitri
# safiselling : safiselling
# penipu : tipu
# jauhkan : jauh
# buang : buang
# aguero : aguero
# semenjak : semenjak
# pensiun : pensiun
# ngomentarin : ngomentarin
# nu : nu
# ngurusin : ngurusin
# ramalan : ramal
# telapak : telapak
# arahin : arahin
# noh : noh
# kbf : kbf
# kimia : kimia
# elin : elin
# bengong : bengong
# sokan : sok
# ngerjain : ngerjain
# inget : inget
# bbrpa : bbrpa
# nebelin : nebelin
# pensil : pensil
# jelekkkk : jelekkkk
# gamauuuu : gamauuuu
# ooh : ooh
# pribumi : pribumi
# jilat : jilat
# binatang : binatang
# setia : setia
# terhormat : hormat
# kecoa : kecoa
# got : got
# peradaban : adab
# sisanya : sisa
# masi : mas
# cakepan : cakep
# daripada : daripada
# sc : sc
# ngehate : ngehate
# peluh : peluh
# leleh : leleh
# hahahahhaha : hahahahhaha
# kunci : kunci
# goblo : goblo
# control : control
# kntl : kntl
# njir : njir
# tenaga : tenaga
# gedean : gede
# mengalami : alami
# kehendak : hendak
# support : support
# speakup : speakup
# dukungan : dukung
# big : big
# just : just
# stupid : stupid
# lawak : lawak
# iniii : iniii
# perasaan : asa
# gaenak : gaenak
# sumpah : sumpah
# dijagain : dijagain
# tkut : tkut
# hayat : hayat
# shoppe : shoppe
# pesanan : pesan
# why : why
# token : token
# listrik : listrik
# jurusan : jurus
# ada apa : ada apa
# tidak jelas : tidak jelas
# dengernya : dengernya
# bangkai : bangkai
# hujan : hujan
# tibatiba : tibatiba
# kna : kna
# polis : polis
# report : report
# suh : suh
# lawyer : lawyer
# kejebila : kejebila
# akta : akta
# bujtisetakat : bujtisetakat
# bg : bg
# hrkena : hrkena
# lk : lk
# bostk : bostk
# jawab : jawab
# moralitas : moralitas
# rendah : rendah
# von : von
# richter : richter
# bedebah : bedebah
# bangsattt : bangsattt
# icoh : icoh
# biarin : biarin
# nape : nape
# nomor : nomor
# bgst : bgst
# ahhhhhhhhh : ahhhhhhhhh
# ih : ih
# typing : typing
# cringe : cringe
# bngt : bngt
# diliat : liat
# au : au
# ew : ew
# lelet : lelet
# licik : licik
# kedonyan : kedonyan
# dijajanin : dijajanin
# ngeluh : ngeluh
# fitnah : fitnah
# tidak pernah : tidak pernah
# pelit : pelit
# jahit : jahit
# mulut : mulut
# muakk : muakk
# mukutnya : mukutnya
# sukanya : suka
# mulu : mulu
# itsme : itsme
# beradab : adab
# nyebar : nyebar
# sumpahin : sumpahin
# berkah : berkah
# sialan : sial
# mo : mo
# mengamuk : amuk
# menidng : menidng
# beli : beli
# bubur : bubur
# ayam : ayam
# playlist : playlist
# direport : direport
# ckck : ckck
# lupain : lupain
# kebesaran : besar
# rencana : rencana
# takdir : takdir
# user : user
# diupdate : diupdate
# miui : miui
# kamera : kamera
# depannya : depan
# hospital : hospital
# satgi : satgi
# terjai : terjai
# pulak : pulak
# betui : betui
# kesabaran : sabar
# setipis : setip
# tisu : tisu
# dibagi : bagi
# could : could
# never : never
# socmed : socmed
# bentukan : bentuk
# balas : balas
# diproses : proses
# astaghfirulloh : astaghfirulloh
# ndak : ndak
# hakimi : hakim
# minum : minum
# kehausan : haus
# perhitungan : hitung
# bau : bau
# busuk : busuk
# susu : susu
# hajar : hajar
# feromon : feromon
# maju : maju
# mungil : mungil
# memukul : pukul
# bawa perasaan : bawa asa
# meinggalkan : meinggalkan
# dalam perjalanan : dalam jalan
# setan : setan
# mreka : mreka
# ujungnya : ujung
# army : army
# katany : katany
# dh : dh
# menggonggong : gonggong
# melulu : melulu
# tuannya : tuan
# moa : moa
# stay : stay
# thank : thank
# jauhjauh : jauhjauh
# limit : limit
# kangen : kangen
# hanbin : hanbin
# nabgis : nabgis
# ua : ua
# sodara : sodara
# pungli : pungli
# dimanamana : dimanamana
# jskskskskdkd : jskskskskdkd
# lucu : lucu
# pilpres : pilpres
# musuh : musuh
# kubu : kubu
# garis : garis
# hinaanya : hinaanya
# detik : detik
# bergabung : gabung
# diterima : terima
# kualitas : kualitas
# fanbase : fanbase
# dirusuhin : dirusuhin
# kyknya : kyknya
# suga : suga
# rilis : rilis
# hilang : hilang
# fotonya : foto
# gara : gara
# ahh : ahh
# belanja : belanja
# bulanan : bulan
# endingnya : endingnya
# logo : logo
# capcutnya : capcutnya
# nyebelin : nyebelin
# lock : lock
# elon : elon
# sayangkuh : sayangkuh
# nyimpan : nyimpan
# materi : materi
# utbk : utbk
# asuk : asuk
# promo : promo
# dagangan : dagang
# shopee : shopee
# kolom : kolom
# reply : reply
# barang : barang
# jualannya : jual
# afiliate : afiliate
# disrespect : disrespect
# jennie : jennie
# dihujat : hujat
# kepleset : kepleset
# jempol : jempol
# thv : thv
# fandom : fandom
# apasih : apasih
# belaian : belai
# forget : forget
# mn : mn
# peduli : peduli
# ngedefend : ngedefend
# defend : defend
# sekesel : sekesel
# lbp : lbp
# jancuk : jancuk
# loe : loe
# pede : pede
# koarkoar : koarkoar
# ngentot : ngentot
# disapa : sapa
# bales : bales
# bangkrut : bangkrut
# jokowisirik : jokowisirik
# kagof : kagof
# komentarnya : komentar
# kongkek : kongkek
# ksel : ksel
# gaya : gaya
# ngomongnya : ngomongnya
# ituloh : ituloh
# taitai : taitai
# redsindo : redsindo
# penggemar : gemar
# taehyung : taehyung
# ngerokok : ngerokok
# abisan : abis
# ngisep : ngisep
# asbak : asbak
# model : model
# marble : marble
# ae : ae
# nark : nark
# jungkok : jungkok
# gwi : gwi
# nam : nam
# daah : daah
# happy : happy
# penjaganya : jaga
# kost : kost
# tampol : tampol
# banner : banner
# raiden : raiden
# cyno : cyno
# nahida : nahida
# dorang : dorang
# kejar : kejar
# nak : nak
# gigit : gigit
# speed : speed
# and : and
# macam : macam
# hahahahakasihan : hahahahakasihan
# yatim : yatim
# ngantuk : ngantuk
# sehari : hari
# tipes : tipes
# fell : fell
# harder : harder
# virtual : virtual
# without : without
# having : having
# aduh : aduh
# strees : strees
# jean : jean
# divaksin : vaksin
# covid : covid
# berguna : guna
# disarankan : saran
# persentase : persentase
# peluang : peluang
# covidnya : covidnya
# dipakai : pakai
# penghindaran : hindar
# pencurian : curi
# terserah : serah
# mual : mual
# cokkk : cokkk
# garuda : garuda
# go : go
# around : around
# runway : runway
# ma : ma
# mas : mas
# halal : halal
# digebukin : digebukin
# cacat : cacat
# seganteng : ganteng
# seungkwaaannnnnn : seungkwaaannnnnn
# gatakut : gatakut
# blink : blink
# pantek : pantek
# bermasalah : masalah
# unnik : unnik
# bangtan : bangtan
# luhut : luhut
# sengaja : sengaja
# menghancurkan : hancur
# terbangun : bangun
# buruk : buruk
# habishabisan : habishabisan
# wkwkwkwkwkwkwkwk : wkwkwkwkwkwkwkwk
# niat : niat
# mainin : mainin
# plis : plis
# bersih : bersih
# jejak : jejak
# pelanggaran : langgar
# ham : ham
# cak : cak
# imin : imin
# ngsih : ngsih
# nick : nick
# baginda : baginda
# baku : baku
# hantam : hantam
# ajalah : aja
# sabar : sabar
# jumpa : jumpa
# criminal : criminal
# offensive : offensive
# side : side
# eye : eye
# kat : kat
# kawin : kawin
# cubit : cubit
# pipi : pipi
# my : my
# cat : cat
# call : call
# her : her
# tengok : tengok
# pegi : pegi
# bazar : bazar
# bebanyak : bebanyak
# ngambil : ngambil
# notif : notif
# memori : memori
# ama : ama
# merekatunggu : merekatunggu
# bentar : bentar
# ngehapusin : ngehapusin
# aplikasi : aplikasi
# nungguin : nungguin
# pinjem : pinjem
# fotbar : fotbar
# jungkook : jungkook
# woi : woi
# ngak : ngak
# ngapangapain : ngapangapain
# nangis : nang
# jelekk : jelekk
# malem : malem
# bisanya : bisa
# flyover : flyover
# untumu : untumu
# baris : baris
# orientasi : orientasi
# homoseksual : homoseksual
# heteroseksual : heteroseksual
# tobat : tobat
# merugikan : rugi
# homo : homo
# implikasi : implikasi
# stress : stress
# menjelang : jelang
# titit : titit
# anjingitu : anjingitu
# arap : arap
# kodok : kodok
# aremaoi : aremaoi
# lolos : lolos
# gasi : gas
# kemampuan : mampu
# kenyataannya : nyata
# sesimple : sesimple
# emng : emng
# serius : serius
# kirain : kirain
# kapus : kapus
# kepergok : pergok
# alasannya : alas
# nukerin : nukerin
# koperasi : koperasi
# pecah : pecah
# iyain : iyain
# pgi : pgi
# fisika : fisika
# np : np
# reflek : reflek
# loyo : loyo
# bukan : bukan
# korup : korup
# segininya : gin
# bkin : bkin
# badmood : badmood
# ngapa : ngapa
# dkira : dkira
# babu : babu
# kudu : kudu
# kerja : kerja
# idup : idup
# bkan : bkan
# hello : hello
# bantai : bantai
# sarapan : sarap
# ngide : ngide
# ngewarnain : ngewarnain
# rambut : rambut
# tante : tante
# girang : girang
# hbs : hbs
# keguguran : gugur
# bekelai : bekelai
# keluarganya : keluarga
# rejeki : rejeki
# lancar : lancar
# jepinnnn : jepinnnn
# jjnya : jjnya
# gembokkk : gembokkk
# nderr : nderr
# pandang : pandang
# touching : touching
# jenis : jenis
# kadarnya : kadar
# subur : subur
# mens : mens
# birahi : birah
# sedikitpun : sedikit
# baiknya : baik
# temuin : temuin
# seksolog : seksolog
# cakep : cakep
# bangettt : bangettt
# sihh : sihh
# cytro : cytro
# parti : parti
# liar : liar
# serang : serang
# jijik : jijik
# maksum : maksum
# cyberbully : cyberbully
# doxxed : doxxed
# embarrassing : embarrassing
# yati : yati
# waluhnya : waluh
# gapapa : gapapa
# ditawarin : ditawarin
# tiket : tiket
# wkwkwkwkwwkwkkwwkwkwkwk : wkwkwkwkwwkwkkwwkwkwkwk
# nambahinnbuat : nambahinnbuat
# vip : vip
# buru : buru
# mainnya : main
# sabtu : sabtu
# sick : sick
# gws : gws
# dek : dek
# mendekati : dekat
# diingetin : diingetin
# ketemu : ketemu
# reonya : reonya
# speechless : speechless
# dalem : dalem
# ...
# firli : firli
# bahuri : bahuri
# terpojok : pojok
# besaran : besar
# karyawan : karyawan
# kpknya : kpknya
# mogok : mogok
# detail : detail
# esdm : esdm
# wkkwkw : wkkwkw
# teman : teman
# kreatif : kreatif
# mengemasnya : emas
# dolan : dolan
# sekret : sekret
# wartawan : wartawan
# mlg : mlg
# popularitas : popularitas
# artifisial : artifisial
# ternakannya : terna
# respek : respek
# aniaya : aniaya
# marioternyata : marioternyata
# davidkorbanpernah : davidkorbanpernah
# ngentt : ngentt
# agh : agh
# mariopelakusebanyak : mariopelakusebanyak
# xkarna : xkarna
# mariopelakumelakukan : mariopelakumelakukan
# penganiayaansebenarnya : penganiayaansebenarnya
# anjingnya : anjing
# kesayngan : kesayngan
# exo : exo
# sehun : hun
# ademkan : adem
# drop : drop
# kesayangan : sayang
# hesteg : hesteg
# birthday : birthday
# ur : ur
# menyediakan : sedia
# paket : paket
# orgb : orgb
# juta : juta
# jt : jt
# goyangx : goyangx
# pot : pot
# biaya : biaya
# urilbutsuitdorok : urilbutsuitdorok
# eve : eve
# versionnya : versionnya
# dinyanyiin : dinyanyiin
# henry : henry
# lau : lau
# inggris : inggris
# enakk : enakk
# oposisi : oposisi
# ajaaaaa : ajaaaaa
# wta : wta
# want : want
# ask : ask
# dinosaur : dinosaur
# dilewati : lewat
# alternatif : alternatif
# tia : tia
# bersihin : bersihin
# meja : meja
# dianggep : dianggep
# sekalinya : sekali
# dipersulit : sulit
# setannnn : setannnn
# nutupin : nutupin
# netijen : netijen
# blokir : blokir
# bisukan : bisu
# nyeoam : nyeoam
# bisikan : bisik
# duanya : dua
# triliyunan : triliyunan
# kontraktor : kontraktor
# projek : projek
# sentul : sentul
# paitnya : paitnya
# ampundi : ampundi
# ampir : ampir
# sebulan : bulan
# jugapadahal : jugapadahal
# hitungan : hitung
# milyaran : milyaran
# tambatan : tambat
# cekup : cekup
# walaunta : walaunta
# ciyeeee : ciyeeee
# mane : mane
# korupsinya : korupsi
# benerin : benerin
# empang : empang
# kriminalitas : kriminalitas
# jalanannya : jalan
# yyyyaaahhhhh : yyyyaaahhhhh
# artis : artis
# pict : pict
# perlekehkan : perlekehkan
# tepuk : tepuk
# sekor : kor
# melayang : layang
# kopiahtudung : kopiahtudung
# explain : explain
# dgan : dgan
# perlekeh : perlekeh
# antonim : antonim
# wkw : wkw
# ikan : ikan
# hiu : hiu
# tomat : tomat
# terbentuk : bentuk
# circle : circle
# penjilatteam : penjilatteam
# suksesdiangkat : suksesdiangkat
# pejabatkorupsimasuk : pejabatkorupsimasuk
# penjarajilat : penjarajilat
# oligarki : oligarki
# dikotori : kotor
# hoaxhoax : hoaxhoax
# bombastis : bombastis
# teranyar : anyar
# bem : bem
# bikinan : bikin
# ns : ns
# raaa : raaa
# rs : rs
# drvgs : drvgs
# besi : besi
# nampan : nampan
# ngira : ngira
# akibat : akibat
# haluin : haluin
# oppa : oppa
# sope : sope
# privasi : privasi
# dipost : dipost
# hadapi : hadap
# risik : risik
# terputus : putus
# energi : energi
# substansial : substansial
# penyaluran : salur
# jps : jps
# tipis : tipis
# disitu : situ
# cenul : cenul
# iniini : iniini
# rakyatdulu : rakyatdulu
# pilkada : pilkada
# care : care
# malaikat : malaikat
# lagak : lagak
# amnesia : amnesia
# eyak : eyak
# wkwkww : wkwkww
# inipelanggaran : inipelanggaran
# maksudganjarkan : maksudganjarkan
# capresbeda : capresbeda
# dicapreskanpintar : dicapreskanpintar
# gaush : gaush
# kosongan : kosong
# buzzerbuzzer : buzzerbuzzer
# pohon : pohon
# terobsesi : obsesi
# book : book
# venue : venue
# kawinan : kawin
# bunderan : bunderan
# hi : hi
# week : week
# speedrun : speedrun
# im : im
# gon : gon
# finish : finish
# lyrics : lyrics
# flame : flame
# espr : espr
# loveit : loveit
# if : if
# constellation : constellation
# imma : imma
# all : all
# verdana : verdana
# sasaran : sasar
# dprd : dprd
# pusat : pusat
# ignorant : ignorant
# taksir : taksir
# kerugian : rugi
# duitnya : duit
# rosiade : rosiade
# mahasiwa : mahasiwa
# bandung : bandung
# sore : sore
# bergerak : gerak
# intelmu : intel
# noo : noo
# jajja : jajja
# egx : egx
# aph : aph
# kpopers : kpopers
# bh : bh
# spek : spek
# clubbing : clubbing
# selagi : selagi
# ngobat : ngobat
# wkwkkw : wkwkkw
# tokonya : toko
# merk : merk
# dipasaran : pasar
# konten : konten
# research : research
# ginian : ginian
# say : say
# goodbye : goodbye
# fav : fav
# military : military
# stream : stream
# flop : flop
# musicnya : musicnya
# losss : losss
# gaperlu : gaperlu
# makanan : makan
# seblak : seblak
# ejek : ejek
# yuhuuu : yuhuuu
# ngajak : ngajak
# gelud : gelud
# sherlock : sherlock
# caur : caur
# tingkah : tingkah
# laku : laku
# yaww : yaww
# nimbrung : nimbrung
# mbanya : mbanya
# ls : ls
# idolny : idolny
# xixi : xixi
# bljr : bljr
# kuping : kuping
# kiri : kiri
# fred : fred
# ball : ball
# incoming : incoming
# motherfuckers : motherfuckers
# dinaikin : dinaikin
# kasusnya : kasus
# narsinghanand : narsinghanand
# menyerukan : seru
# merebut : rebut
# pbnu : pbnu
# menyayangkan : sayang
# gedeu : gedeu
# tuuh : tuuh
# bayarannya : bayar
# berapaa : berapaa
# siihhh : siihhh
# ros : ros
# another : another
# berperasaan : rasa
# keonaran : onar
# iamdemo : iamdemo
# abeg : abeg
# shey : shey
# lege : lege
# wala : wala
# din : din
# evaluator : evaluator
# sa : sa
# gurame : gurame
# hujat : hujat
# try : try
# test : test
# urut : urut
# intimate : intimate
# client : client
# sorang : sorang
# merinding : merinding
# mukidi : mukidi
# woyyyyy : woyyyyy
# bule : bule
# setega : tega
# anjenglah : anjenglah
# mangat : mangat
# ompong : ompong
# mmng : mmng
# sejati : sejati
# persen : persen
# sekar : sekar
# ketakutan : takut
# penampakan : tampak
# iran : iran
# mall : mall
# teheran : teheran
# paska : paska
# mahsa : mahsa
# amini : amin
# menebus : tebus
# dimuliakanlah : mulia
# doakan : doa
# beringas : beringas
# dijamah : jamah
# kecap : kecap
# ransum : ransum
# sekai : seka
# mempertahankan : tahan
# kegoblo : kegoblo
# ngalah : ngalah
# kikin : kikin
# liarjadi : liarjadi
# lagihemmm : lagihemmm
# meresahkan : resah
# tingkat : tingkat
# bangka : bangka
# tanahbisanya : tanahbisanya
# bogorkerja : bogorkerja
# aniesyang : aniesyang
# bergaunggaungnya : bergaunggaungnya
# kencang : kencang
# buzzerharusnya : buzzerharusnya
# medsosnya : medsosnya
# suaranyajgn : suaranyajgn
# stigma : stigma
# opik : opik
# dibohongi : bohong
# foya : foya
# bininya : bini
# gapenting : gapenting
# gabakal : gabakal
# walah : walah
# hendarji : hendarji
# nganu : nganu
# massssss : massssss
# lapar : lapar
# fitrahnya : fitrah
# harambakal : harambakal
# provokatorgak : provokatorgak
# liarhanya : liarhanya
# masyarakatmainan : masyarakatmainan
# medsoshemmm : medsoshemmm
# malingmerasa : malingmerasa
# sucibenartapi : sucibenartapi
# buron : buron
# dilantik : lantik
# statusnya : status
# polisinya : polisi
# belom : bom
# kering : kering
# nongol : nongol
# orba : orba
# setara : tara
# institute : institute
# pbhi : pbhi
# oreo : oreo
# tercetak : cetak
# serasi : serasi
# cekcok : cekcok
# sugesti : sugesti
# jaringan : jaring
# siarkan : siar
# tvgiliran : tvgiliran
# tayangkanoligarki : tayangkanoligarki
# perbanyak : banyak
# kendor : kendor
# kebusukan : busuk
# benalu : benalu
# kerakusannya : rakus
# menimbun : timbun
# kekayaan : kaya
# kelewat : lewat
# sendi : sendi
# nikmati : nikmat
# utangan : utang
# bas : bas
# massal : massal
# senyumin : senyumin
# biasain : biasain
# lepasin : lepasin
# semudah : mudah
# kalii : kali
# waduhada : waduhada
# alamat : alamat
# cost : cost
# saving : saving
# extra : extra
# expense : expense
# melupakan : lupa
# trending : trending
# buzzerakun : buzzerakun
# bokeptukang : bokeptukang
# gaksi : gaksi
# fitur : fitur
# diramein : diramein
# buzz : buzz
# nobaby : nobaby
# hahhaa : hahhaa
# betull : betull
# selingkuh : selingkuh
# kerenan : keren
# doi : doi
# libur : libur
# syuting : syuting
# nyamuk : nyamuk
# setujutdk : setujutdk
# pr : pr
# kapasitas : kapasitas
# masaltapi : masaltapi
# malutapi : malutapi
# curang : curang
# ekwk : ekwk
# yamidan : yamidan
# cracia : cracia
# kkkkk : kkkkk
# pdjl : pdjl
# bom : bom
# ngincer : ngincer
# kirinya : kiri
# bodohin : bodohin
# templet : templet
# spill : spill
# laen : laen
# ngebecandain : ngebecandain
# jav : jav
# ndar : ndar
# berkeberatan : rat
# mengajukan : aju
# gugatan : gugat
# mencicipi : cicip
# korupsinyasebab : korupsinyasebab
# ntk : ntk
# kurangnya : kurang
# bws : bws
# kerjaannya : kerja
# saltyin : saltyin
# harmless : harmless
# muji : muji
# win : win
# nyindir : nyindir
# series : series
# diserok : serok
# bersilid : bersilid
# silid : silid
# asisten : asisten
# rmh : rmh
# tanggaku : tangga
# pengagum : kagum
# bi : bi
# mengagumi : kagum
# slalu : slalu
# muncung : muncung
# mingkem : mingkem
# atm : atm
# amik : amik
# card : card
# blah : blah
# huhu : huhu
# ancelotti : ancelotti
# sopan : sopan
# diresmiin : diresmiin
# keciduk : ciduk
# iyalah : iya
# hatipikirannya : hatipikirannya
# rakuat : rakuat
# geeess : geeess
# uwes : uwes
# taaaa : taaaa
# geess : geess
# halahh : halahh
# parak : parak
# tapir : tapir
# astagfirullah : astagfirullah
# panggilan : panggil
# tandanya : tanda
# menghormati : hormat
# teteh : teteh
# komunitas : komunitas
# aktivis : aktivis
# muda : muda
# indonesiakami : indonesiakami
# telur : telur
# singki : singki
# work : work
# life : life
# balance : balance
# very : very
# long : long
# holiday : holiday
# banyaknya : banyak
# flight : flight
# terganggu : ganggu
# warnain : warnain
# comeback : comeback
# airport : airport
# ln : ln
# dipenjara : penjara
# kelindes : kelindes
# kontener : kontener
# bicra : bicra
# pintar : pintar
# persn : persn
# rusaknya : rusak
# abpntpi : abpntpi
# salud : salud
# kompak : kompak
# restu : restu
# dibantah : ban
# sekjen : sekjen
# berjamaah : jamaah
# disitukan : situ
# ditulia : ditulia
# keluaran : keluar
# anj : anj
# tahunnya : tahun
# weezie : weezie
# nyaya : nyaya
# tendensiussok : tendensiussok
# dijual : jual
# berkoalisi : koalisi
# kadey : kadey
# dik : dik
# serabut : serabut
# nyo : nyo
# palo : palo
# lamo : lamo
# duk : duk
# takey : takey
# tokleh : tokleh
# okk : okk
# doh : doh
# kito : kito
# wali : wali
# palopo : palopo
# fasilitas : fasilitas
# buzzerp : buzzerp
# ketololan : tolol
# apbn : apbn
# slahslah : slahslah
# bahrawipenghianat : bahrawipenghianat
# terbuktimereka : terbuktimereka
# tergabung : gabung
# pkigo : pkigo
# redmi : redmi
# note : note
# keditaan : keditaan
# ingetin : ingetin
# nazaruddin : nazaruddin
# broanas : broanas
# pusaran : pusar
# hambalangcontoh : hambalangcontoh
# radikalakibat : radikalakibat
# temanmenteror : temanmenteror
# kebencianhidup : kebencianhidup
# uncover : uncover
# ayu : ayu
# rapopo : rapopo
# mbokyo : mbokyo
# golek : golek
# sugih : sugih
# gek : gek
# diporoti : porot
# ngono : ngono
# yee : yee
# christ : christ
# mutusin : mutusin
# mr : mr
# beast : beast
# nolongin : nolongin
# tiati : tiati
# marala : marala
# nuranibukan : nuranibukan
# pantesan : pantesan
# dusun : dusun
# pajero : pajero
# wakakaka : wakakaka
# segitunya : segitunya
# ketikannya : keti
# gitupemberontak : gitupemberontak
# gitumudah : gitumudah
# melabeli : label
# ituapakah : ituapakah
# pancasilangacaorang : pancasilangacaorang
# loelangsung : loelangsung
# labeli : label
# berasapa : berasapa
# sifat : sifat
# pancasilaissampah : pancasilaissampah
# indomy : indomy
# monster : monster
# streaming : streaming
# sekedar : dar
# doyan : doyan
# wer : wer
# wor : wor
# visual : visual
# baacoottt : baacoottt
# anter : anter
# brader : brader
# masamu : masa
# mrasa : mrasa
# rohadi : rohadi
# melakulan : melakulan
# semarang : semarang
# suarakan : suara
# infrastruktur : infrastruktur
# pajak : pajak
# tlh : tlh
# dikutip : kutip
# kembalikah : kembali
# kakap : kakap
# diundang : undang
# kemenkeu : kemenkeu
# oooo : oooo
# komisioner : komisioner
# tahsaat : tahsaat
# cacad : cacad
# noda : noda
# bacotnya : bacot
# ketolong : tolong
# bocorin : bocorin
# pinterin : pinterin
# typical : typical
# khawarij : khawarij
# suai : suai
# lahapakah : lahapakah
# cebongers : cebongers
# didalamny : didalamny
# yaqin : yaqin
# selvie : selvie
# solah : solah
# memperjuangakn : memperjuangakn
# itung : itung
# diselesaikan : selesai
# wkwkwkudah : wkwkwkudah
# lainmalu : lainmalu
# gembar : gembar
# tuduh : tuduh
# kebalikanyaemang : kebalikanyaemang
# merubah : rubah
# sapiens : sapiens
# beriman : iman
# menemukan : temu
# delusional : delusional
# mukanya : muka
# panel : panel
# barus : barus
# {'pasal': 'pasal', 'uu': 'uu', 'tpks': 'tpks', 'udah': 'udah', 'dikatakan': 'kata', 'keterangan': 'terang', 'korban': 'korban', 'membuktikan': 'bukti', 'pelecehan': 'leceh', 'seksual': 'seksual', 'minimal': 'minimal', 'aparat': 'aparat', 'penegak': 'tegak', 'hukum': 'hukum', 'ikut': 'ikut', 'atas': 'atas', 'berita': 'berita', 'undang undang': 'undang undang', 'bertindak': 'tindak', 'jalur': 'jalur', 'viral': 'viral', 'rismawidiono': 'rismawidiono', 'memiliki': 'milik', 'anggapan': 'anggap', 'teroris': 'teroris', 'ditangkap': 'tangkap', 'keimanan': 'iman', 'menganggap': 'anggap', 'berjuang': 'juang', 'penegakan': 'tega', 'agama': 'agama', 'terorisme': 'terorisme', 'agamanya': 'agama', 'menganjurkan': 'anjur', 'penganutnya': 'anut', 'menggandeng': 'gandeng', 'kemenag': 'kemenag', 'mengevaluasi': 'evaluasi', 'pondok': 'pondok', 'pesantren': 'pesantren', 'lokasi': 'lokasi', 'sekolah': 'sekolah', 'madrasah': 'madrasah', 'bully': 'bully', 'diserang': 'serang', 'dipojokan': 'pojok', 'arah': 'arah', 'hina': 'hina', 'cinta': 'cinta', 'dapatkan': 'dapat', 'cacian': 'caci', 'nusantara': 'nusantara', 'mui': 'mui', 'keras': 'keras', 'mencegah': 'cegah', 'marak': 'marak', 'ganjar': 'ganjar', 'pranowo': 'pranowo', 'tertawa': 'tertawa', 'berani': 'berani', 'tipu': 'tipu', 'rakyat': 'rakyat', 'belum': 'belum', 'warga internet': 'warga internet', 'sekarang': 'sekarang', 'banyak': 'banyak', 'cerdas': 'cerdas', 'kekeliruan': 'keliru', 'komentar': 'komentar', 'gemas': 'gemas', 'dalai': 'dalai', 'koruptor': 'koruptor', 'anas': 'anas', 'urbaningrum': 'urbaningrum', 'umur': 'umur', 'agnes': 'agnes', 'madrid': 'madrid', 'chelsea': 'chelsea', 'champions': 'champions', 'league': 'league', 'manchaster': 'manchaster', 'city': 'city', 'monas': 'monas', 'benzema': 'benzema', 'apapun': 'apa', 'waw': 'waw', 'aku': 'aku', 'benar': 'benar', 'sukses': 'sukses', 'ranah': 'ranah', 'semacamnya': 'macam', 'ingin': 'ingin', 'ubah': 'ubah', 'kebiri': 'kebiri', 'mematikan': 'mati', 'hawa': 'hawa', 'napsu': 'napsu', 'pelaku': 'laku', 'jujur': 'jujur', 'tidak suka': 'tidak suka', 'mati': 'mati', 'mudah': 'mudah', 'tinggal': 'tinggal', 'doang': 'doang', 'siang': 'siang', 'mengatasnamakan': 'mengatasnamakan', 'relawan': 'rawan', 'membagikan': 'bagi', 'kaos': 'kaos', 'dompet': 'dompet', 'rumah': 'rumah', 'warga': 'warga', 'halang': 'halang', 'kenderaan': 'kenderaan', 'gangguan': 'ganggu', 'perbuatan': 'buat', 'pemandu': 'pandu', 'kelisa': 'kelisa', 'undang': 'undang', 'kemarahan': 'marah', 'udahlah': 'udahlah', 'cholil': 'cholil', 'berpolemik': 'polemik', 'jalankan': 'jalan', 'sesuai': 'sesuai', 'konstitusi': 'konstitusi', 'lakukanlah': 'laku', 'jel': 'jel', 'kacer': 'kacer', 'bahrawi': 'bahrawi', 'lebar': 'lebar', 'nulis': 'nulis', 'semangatnya': 'semangat', 'hnya': 'hnya', 'rasis': 'ras', 'kebencian': 'benci', 'keturunan': 'turun', 'cina': 'cina', 'warna': 'warna', 'it': 'it', 'ustazah': 'ustazah', 'tu': 'tu', 'cakap': 'cakap', 'in': 'in', 'marriage': 'marriage', 'ni': 'ni', 'sometimes': 'sometimes', 'mak': 'mak', 'ajar': 'ajar', 'so': 'so', 'isterisuami': 'isterisuami', 'kena': 'kena', 'belajar': 'ajar', 'orang': 'orang', 'diajar': 'ajar', 'bodoh': 'bodoh', 'sombong': 'sombong', 'tunggang': 'tunggang', 'jugak': 'jugak', 'demokrat': 'demokrat', 'menormalisasi': 'normalisasi', 'perampokan': 'ampo', 'shoplifting': 'shoplifting', 'alasan': 'alas', 'woke': 'woke', 'culture': 'culture', 'melawan': 'lawan', 'peraturan': 'atur', 'didak': 'didak', 'jateng': 'jateng', 'terlarang': 'larang', 'tuk': 'tuk', 'produksi': 'produksi', 'jualan': 'jual', 'petasan': 'petas', 'sejenisnya': 'jenis', 'su': 'su', 'sendernya': 'sender', 'tertarik': 'tarik', 'dideketin': 'dideketin', 'penganut': 'anut', 'komen': 'komen', 'sepert': 'sepert', 'salah': 'salah', 'acuan': 'acu', 'jurnalisme': 'jurnalisme', 'lurus': 'lurus', 'terjebak': 'jebak', 'politik': 'politik', 'keberpihakan': 'pihak', 'muhaimin': 'muhaimin', 'iskandar': 'iskandar', 'puan': 'puan', 'mahal': 'mahal', 'erick': 'erick', 'thohir': 't ...
# ------------------------
# Pandas Apply:   0%|          | 0/1681 [00:00<?, ?it/s]
# Stemmer :
#
# 0       [pasal, uu, tpks, udah, kata, terang, korban, ...
# 1                                          [rismawidiono]
# 2       [milik, anggap, teroris, tangkap, milik, iman,...
# 3       [gandeng, kemenag, evaluasi, pondok, pesantren...
# 4       [bully, serang, pojok, arah, hina, cinta, dapa...
#                               ...
# 1676       [capres, imigran, yaman, rubah, ulama, buzzer]
# 1677    [yaudah, biarin, yaudah, senyumin, yaudah, lup...
# 1678    [sapiens, iman, iman, temu, tuhan, delusional,...
# 1679    [munafik, politisasi, politik, usak, pancasila...
# 1680    [prabowo, subianto, persen, ganjar, pranowo, p...
# Name: tweet_tokens_stemmed, Length: 1681, dtype: object

# %%
import csv

# Read CSV
with open('dataHS_01_normal.csv', 'r') as csv_file:
    csv_reader = csv.reader(csv_file)
    
    # Creates an empty list to store each row
    rows = []
    
    # Iterate over each line in the CSV file
    for row in csv_reader:
        # Retrieve the values from both columns
        column1 = row[0]
        
        # Converts data to a string without quotes and parentheses
        column1 = column1.replace("[", "").replace("]", "").replace("'", "").replace(",", "")
       
        # Combines the values from both columns with spaces and adds a new row
        row_data = column1 + "\n"

        # Adding rows to the list rows
        rows.append(row_data)

# Writes each line into a text file
with open('dataTEXT01.txt', 'w') as txt_file:
    txt_file.writelines(rows)

# %%
with open('dataTEXT01.txt', 'r') as file:
    article = file.read()
article
# Out:
# 'tweet_normalized\npasal uu tpks udah dikatakan keterangan korban membuktikan pelecehan seksual minimal aparat penegak hukum ikut atas berita undang undang bertindak jalur viral\nrismawidiono\nmemiliki anggapan teroris ditangkap memiliki keimanan menganggap ditangkap berjuang penegakan agama terorisme agamanya agama menganjurkan penganutnya\nmenggandeng kemenag mengevaluasi pondok pesantren lokasi sekolah madrasah\nbully diserang dipojokan arah hina cinta dapatkan cacian\nnusantara mui keras mencegah pelecehan seksual pesantren marak\nganjar pranowo tertawa berani tipu rakyat belum warga internet sekarang banyak cerdas tertawa kekeliruan komentar gemas dalai koruptor anas urbaningrum umur agnes madrid chelsea champions league manchaster city monas benzema\napapun waw aku benar sukses ranah hukum semacamnya ingin aku ubah hukum kebiri mematikan hawa napsu pelaku pelecehan udah jujur aku tidak suka hukum mati mudah tertawa tinggal mati doang\nsiang mengatasnamakan relawan ganjar pranowo membagikan kaos dompet rumah warga\nhalang kenderaan gangguan seksual perbuatan pemandu kelisa undang kemarahan warga internet\nudahlah cholil berpolemik jalankan sesuai konstitusi lakukanlah pasal jel\nkacer bahrawi lebar nulis semangatnya hnya rasis kebencian keturunan cina warna it\nustazah tu cakap in marriage ni sometimes mak ajar so isterisuami kena ajar belajar kena orang diajar bodoh sombong tunggang agama jugak\ndemokrat menormalisasi perampokan shoplifting alasan woke culture orang melawan peraturan didak\nwarga jateng terlarang tuk produksi jualan petasan sejenisnya su\nsendernya agama tertarik agama dideketin penganut agama komen sepert\nsalah acuan jurnalisme lurus terjebak politik keberpihakan\nmuhaimin iskandar puan mahal erick thohir\nprabowo subianto ganjar pranowo anies baswedan\nprabowo subianto unggul gubernur jawa ganjar pranowo anies baswedan\nudah segender beda agama miris sekali\nkadal gurun gambar akimu\nistiqomah roger danuarta cut meyriska ajarkan anak agama\nali memiliki catatan hitam warga wadas kendeng saksi hidup slogan tuan ku rakyat omong kosong\nkadal gurun tidak mh bnyak malas aje ngider nyari jajanan aye tinggal bogor lupa jajanan bogor yak\nvisit filled dengan happiness ganjar pranowos visit to the orphanage where talented resident mala receives laptop gift from ganjar\nlttd border px solid baru msodataplacementsamecellgt\nsender bingung nanya base kristen pendetanya islam ustadnya masingmasing pemuka agama sender berharap nanya modelan begini base hadeh aneh sekali\nintinya susah ijin rumah ibadah agama mayoritassederhana\nwahh mantappp ganjar dicapreskan menguntungkan anies baswedan capres anies baswedan prabowo subianto ganjar pranowo suara jokowi masuk prabowo suara prabowo mendukung prabowo heheheh\ncoba nama agama maksud nama agama\nsetidaknya astaga seksual serangan pelecehan krl terus diinjak diremehkan harga\ngsp aku ngegas ag hukuman maximal rekaman aktivitas seksual diumbar seindonesia raya udah\nanimeind update terbaru genshin impact perbincangan pemain nama cerita hadir gamenya dis\nmeta subekti pemberian insentif pemprov jateng kpada sbagai pengajar agama budha patut\nalquds internasional argumen zionis membenarkan penjajahan israel palestina memiliki dasar akal sehat legal sejarah agama malcolm\nkampungan kalah debat bawa agama\nthread bagus misteri menerima cinta tuhan menerimanya agama mengajarkan sibuk berteduh membentengi darinya bersyukur menulis bahasa indonesia dimana tuhan multitafsir universal\nagama kepercayaan dianut kamu nyaman seneng kamu susah sengsara kamu diuji kayak kamu diombangambing keras kamu pastiin kamu kuat\nsampe kamu pindah kamu nemu crush muslim eh kamu goyah pondasi kamu agama belum kokoh tanyain sama nder kamu percaya kamu nyaman kamu sengsara susah\npelecehan seksual melaporkan orang bersangkutan korban langsung kalau korban umur berhak melaporkan orangtuanya nikah pasangan hak melaporkan syarat lapor minimal alat bukti\nagama orang pindah crush tinggalin agamamu ny ...

# %%
from polyglot.text import Text

# Create a new text object using Polyglot's Text class: txt
txt = Text(article)

ner_tags = txt.entities
txt.entities
# Out:
# [I-ORG(['mui']),
#  I-PER(['anas']),
#  I-PER(['agnes']),
#  I-ORG(['agnes', 'madrid', 'chelsea']),
#  I-PER(['cholil']),
#  I-LOC(['jateng']),
#  I-PER(['muhaimin', 'iskandar']),
#  I-PER(['erick', 'thohir', 'prabowo', 'subianto']),
#  I-PER(['anies']),
#  I-PER(['prabowo', 'subianto']),
#  I-PER(['anies']),
#  I-PER(['roger', 'danuarta']),
#  I-PER(['anies']),
#  I-PER(['anies', 'baswedan', 'prabowo', 'subianto']),
#  I-PER(['jokowi']),
#  I-PER(['prabowo']),
#  I-PER(['prabowo']),
#  I-PER(['prabowo']),
#  I-LOC(['jateng']),
#  I-LOC(['palestina']),
#  I-PER(['malcolm']),
#  I-LOC(['afganistan']),
#  I-PER(['fx']),
#  I-LOC(['boyolali']),
#  I-PER(['joko', 'widodo']),
#  I-LOC(['korsel']),
#  I-LOC(['jateng']),
#  I-PER(['ahmad']),
#  I-LOC(['agong']),
#  I-PER(['joko', 'widodo', 'jokowi']),
#  I-PER(['agnes']),
#  I-PER(['amatan']),
#  I-PER(['joko', 'widodo', 'jokowi']),
#  I-ORG(['jateng']),
#  I-PER(['jateng', 'agnes']),
#  I-PER(['inzaghi', 'ash']),
#  I-PER(['arbana', 'kristi']),
#  I-PER(['jane']),
#  I-PER(['kristi']),
#  I-PER(['pranowo']),
#  I-PER(['joko', 'widodo']),
#  I-PER(['agnes']),
#  I-PER(['joko', 'widodo']),
#  I-PER(['agnes']),
#  I-PER(['gemas', 'inzaghi', 'dalai']),
#  I-LOC(['pki']),
#  I-LOC(['jateng']),
#  I-LOC(['nusantara']),
#  I-PER(['jane']),
#  I-PER(['kristi']),
#  I-PER(['jane']),
#  I-PER(['dandy']),
#  I-PER(['david']),
#  I-PER(['agnes']),
#  I-PER(['agnes', 'agnes']),
#  I-ORG(['rep']),
#  I-ORG(['jokowi']),
#  I-PER(['diem']),
#  I-PER(['agnes']),
#  I-PER(['prabowo']),
#  I-PER(['lucas']),
#  I-LOC(['jateng']),
#  I-LOC(['aqsa']),
#  I-PER(['qu']),
#  I-PER(['jokowi']),
#  I-PER(['sheikh', 'al', 'zayed']),
#  I-PER(['jokowi']),
#  I-LOC(['jateng', 'ganjar']),
#  I-PER(['jokowi']),
#  I-PER(['jokowi']),
#  I-PER(['anies', 'baswedan', 'gus', 'yazid']),
#  I-PER(['muhammad']),
#  I-PER(['prabowo']),
#  I-PER(['zon']),
#  I-PER(['prabowo']),
#  I-PER(['jokowi']),
#  I-LOC(['sumenep']),
#  I-PER(['jokowi']),
#  I-LOC(['sumenep']),
#  I-PER(['joko', 'widodo']),
#  I-PER(['joko', 'widodo']),
#  I-PER(['yuni']),
#  I-PER(['pranowo']),
#  I-PER(['ag']),
#  I-PER(['ibnul', 'qayyim']),
#  I-PER(['jokowi']),
#  I-LOC(['yaman']),
#  I-LOC(['hadramaut', 'yaman']),
#  I-LOC(['indonesia']),
#  I-LOC(['jateng']),
#  I-LOC(['jateng']),
#  I-LOC(['kufah']),
#  I-LOC(['tibet']),
#  I-PER(['diem']),
#  I-PER(['agnes']),
#  I-PER(['jelasin']),
#  I-LOC(['ugm']),
#  I-PER(['abraham', 'samad']),
#  I-PER(['anas']),
#  I-LOC(['saar']),
#  I-PER(['loren']),
#  I-PER(['rush']),
#  I-PER(['lee']),
#  I-PER(['prim']),
#  I-PER(['sukarno']),
#  I-PER(['prabowo']),
#  I-PER(['prabowo']),
#  I-PER(['elon']),
#  I-LOC(['yaman']),
#  I-PER(['jokowi']),
#  I-PER(['jokowi']),
#  I-PER(['prabowo']),
#  I-ORG(['pgi']),
#  I-LOC(['sumbar']),
#  I-PER(['lulu']),
#  I-LOC(['sulawesi']),
#  I-PER(['tf']),
#  I-PER(['gus']),
#  I-LOC(['bayern']),
#  I-LOC(['kebayoran']),
#  I-LOC(['bekasi']),
#  I-LOC(['utah']),
#  I-PER(['diem']),
#  I-LOC(['pelecehanberusaha']),
#  I-PER(['jokowi']),
#  I-ORG(['jokowi']),
#  I-PER(['cawapres']),
#  I-PER(['brin', 'prof']),
#  I-PER(['sayidina', 'umar']),
#  I-LOC(['papua']),
#  I-ORG(['pertamina']),
#  I-PER(['bahar', 'smith']),
#  I-PER(['ono']),
#  I-ORG(['brp']),
#  I-LOC(['mekkah']),
#  I-PER(['maguire']),
#  I-LOC(['sevilla']),
#  I-PER(['maxim']),
#  I-PER(['koplak']),
#  I-LOC(['lumajang']),
#  I-LOC(['majene']),
#  I-LOC(['tpi']),
#  I-ORG(['partainya']),
#  I-LOC(['boyolali']),
#  I-PER(['iis', 'dahlia']),
#  I-PER(['prabowo']),
#  I-PER(['anies']),
#  I-LOC(['yaman']),
#  I-PER(['agnes']),
#  I-LOC(['samosir']),
#  I-PER(['efendi']),
#  I-PER(['anies']),
#  I-PER(['anies', 'baswedan']),
#  I-PER(['hajar']),
#  I-LOC(['cuba']),
#  I-LOC(['tabanan']),
#  I-LOC(['tabanan']),
#  I-LOC(['tabanan']),
#  I-LOC(['tabanan']),
#  I-PER(['jk']),
#  I-LOC(['palestina']),
#  I-LOC(['yaman']),
#  I-PER(['eneng']),
#  I-PER(['anies']),
#  I-LOC(['pasangkayu']),
#  I-LOC(['palestina']),
#  I-PER(['musa']),
#  I-LOC(['papua']),
#  I-PER(['anies']),
#  I-PER(['anies']),
#  I-PER(['ariel']),
#  I-PER(['reborn']),
#  I-PER(['netanyahu']),
#  I-LOC(['bangor']),
#  I-ORG(['indonesia']),
#  I-LOC(['palestina']),
#  I-LOC(['makkah']),
#  I-LOC(['dki']),
#  I-LOC(['palestina']),
#  I-LOC(['palestina']),
#  I-PER(['blom']),
#  I-ORG(['pbb']),
#  I-ORG(['tpi']),
#  I-LOC(['bangladesh']),
#  I-LOC(['nusantara']),
#  I-PER(['tikadrun']),
#  I-PER(['fpi']),
#  I-ORG(['pemerintahnya']),
#  I-LOC(['palestina']),
#  I-PER(['anies']),
#  I-ORG(['sby']),
#  I-LOC(['kusan']),
#  I-LOC(['pagatan', 'kalsel']),
#  I-LOC(['boto']),
#  I-PER(['priantoro']),
#  I-PER(['bobby']),
#  I-PER(['neno']),
#  I-PER(['sarumpaet']),
#  I-PER(['anie']),
#  I-PER(['neopki']),
#  I-PER(['loren']),
#  I-PER(['prabowo']),
#  I-LOC(['palestina']),
#  I-ORG(['tpi']),
#  I-LOC(['yaman', 'yaman']),
#  I-PER(['aidit']),
#  I-LOC(['yaman']),
#  I-LOC(['yaman']),
#  I-LOC(['bangor']),
#  I-LOC(['palestina']),
#  I-LOC(['samosir']),
#  I-LOC(['ntt']),
#  I-PER(['sby']),
#  I-LOC(['mekah']),
#  I-ORG(['palestine']),
#  I-LOC(['yaman']),
#  I-LOC(['palestina']),
#  I-PER(['anies']),
#  I-ORG(['pilpres']),
#  I-LOC(['nyundul']),
#  I-PER(['yohanes']),
#  I-PER(['anies']),
#  I-LOC(['afganistan']),
#  I-PER(['kam', 'baskoro']),
#  I-PER(['anies']),
#  I-PER(['jokowi']),
#  I-LOC(['yaman']),
#  I-PER(['bahar']),
#  I-PER(['koo']),
#  I-PER(['shanty']),
#  I-PER(['taliban']),
#  I-ORG(['tpi']),
#  I-PER(['prabowo']),
#  I-LOC(['palestina']),
#  I-PER(['glazer']),
#  I-PER(['zionist']),
#  I-LOC(['palestina']),
#  I-PER(['anies']),
#  I-PER(['anies']),
#  I-LOC(['samosir']),
#  I-PER(['prabowo']),
#  I-PER(['maguire']),
#  I-PER(['gordon', 'ramsay']),
#  I-PER(['jokowi']),
#  I-ORG(['hawks']),
#  I-PER(['jeff', 'bezos']),
#  I-LOC(['parigi']),
#  I-PER(['lee']),
#  I-PER(['abdullah']),
#  I-LOC(['babylon']),
#  I-LOC(['olympia']),
#  I-LOC(['babylon']),
#  I-PER(['disney']),
#  I-PER(['disney']),
#  I-PER(['ares']),
#  I-PER(['finberland']),
#  I-PER(['yohanes', 'pembaptis']),
#  I-LOC(['joho']),
#  I-PER(['lee']),
#  I-PER(['kentung']),
#  I-PER(['pangalila']),
#  I-PER(['gibran']),
#  I-PER(['lisa']),
#  I-PER(['jk']),
#  I-ORG(['diponegoro']),
#  I-PER(['nakula']),
#  I-PER(['palace']),
#  I-PER(['prabowo']),
#  I-PER(['rahul', 'gandhi']),
#  I-PER(['anies']),
#  I-PER(['jokowi']),
#  I-LOC(['samosir']),
#  I-LOC(['palestina']),
#  I-LOC(['palestina', 'al']),
#  I-PER(['anies']),
#  I-PER(['ag']),
#  I-PER(['mario']),
#  I-ORG(['brp']),
#  I-PER(['rizal']),
#  I-PER(['pramono']),
#  I-PER(['dolan']),
#  I-PER(['erick']),
#  I-PER(['david']),
#  I-PER(['henry']),
#  I-PER(['tia']),
#  I-LOC(['sentul']),
#  I-PER(['agnes']),
#  I-PER(['anies']),
#  I-PER(['anies']),
#  I-ORG(['chelsea']),
#  I-LOC(['samosir']),
#  I-PER(['anies']),
#  I-LOC(['bandung']),
#  I-PER(['agnes']),
#  I-LOC(['mekah']),
#  I-PER(['pbnu']),
#  I-PER(['anies']),
#  I-LOC(['iran']),
#  I-LOC(['teheran']),
#  I-LOC(['iran']),
#  I-PER(['anies']),
#  I-LOC(['yaman']),
#  I-LOC(['palestina']),
#  I-LOC(['iran']),
#  I-LOC(['teheran']),
#  I-LOC(['iran']),
#  I-PER(['anies']),
#  I-PER(['ps']),
#  I-PER(['doi']),
#  I-PER(['jokowi']),
#  I-PER(['ndar']),
#  I-PER(['tanggaku']),
#  I-PER(['jokowi']),
#  I-PER(['jokowi']),
#  I-PER(['anies']),
#  I-PER(['ancelotti']),
#  I-ORG(['tpi']),
#  I-LOC(['palopo']),
#  I-PER(['loe']),
#  I-LOC(['samosir']),
#  I-LOC(['ntt']),
#  I-PER(['jokowi']),
#  I-PER(['diem']),
#  I-PER(['anies']),
#  I-PER(['hasibuan']),
#  I-LOC(['suai']),
#  I-PER(['anies']),
#  I-LOC(['yaman']),
#  I-PER(['prabowo']),
#  I-PER(['prabowo']),
#  I-PER(['prabowo'])]

# %%
# Creates a Text object for each sentence in the text
result_ner = []
for sentence in article:
    txt = Text(article)
    result_ner.append(txt.entities)

# Combining the NER results for each sentence
result_merge = []
for sentence_ner in result_ner:
    merge = ""
    for entities in sentence_ner:
        tag = entities.tag
        text = entities[0]
        merge += f"<I-{tag}/>{text} "
result_merge.append(merge.strip())

# Save results to a file
with open("data.txt", "w", encoding="utf-8") as file:
    for result in result_merge:
        file.write(result + "\n")

# %%
txt = Text(article)

# Initialize the count variable: count
count = 0

# Iterate over all the entities
for ent in txt.entities:
    # check whether the entity contains 'Anies'
    if ('anies' in ent):
        # Increment count
        count += 1
        
# Print count
print(count)

# Calculate the percentage of entities that refer to "Gabo": percentage
percentage = count / len(txt.entities)
print(percentage)
# Out:
# 28
# 0.08459214501510574

# %%
x = 5
y = 20
print (x|y)
# Out:
# 21
